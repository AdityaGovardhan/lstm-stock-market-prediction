# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import io
# %matplotlib inline

# %%
df=pd.read_csv('stock.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-2a6dc2ced74a> in <module>()
# ----> 1 df=pd.read_csv('stock.csv')
#       2 df.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'stock.csv' does not exist

# %%
df.tail()
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 1003  2019-03-04  21.520000  21.610001  21.320000  21.389999  21.389999
# 1004  2019-03-05  21.410000  21.650000  21.280001  21.549999  21.549999
# 1005  2019-03-06  21.480000  21.480000  20.660000  20.780001  20.780001
# 1006  2019-03-07  20.809999  20.809999  20.340000  20.570000  20.570000
# 1007  2019-03-08  20.410000  21.100000  20.410000  20.990000  20.990000
#
#       Volume
# 1003  103900
# 1004  110900
# 1005   94700
# 1006   95800
# 1007  138000

# %%
closing_data=df['Close'].values
closing_data
# Out:
# array([23.9     , 23.950001, 24.059999, ..., 20.780001, 20.57    ,
#        20.99    ])

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_data=scaler.fit_transform(closing_data.reshape(-1,1))

# %%
len(scaled_data)
# Out:
# 1008

# %%
plt.figure(figsize=(16, 7))
plt.plot(scaled_data)
plt.xlabel('index')
plt.ylabel('Scaled Closing Price')
plt.title('Stock Price')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
def window_data(data,w):
    X=[]
    y=[]
    
    i=0
    while (i+w)<=len(data)-1:
        X.append(data[i:i+w])
        y.append(data[i+w])
        
        i=i+1
        assert len(X)==len(y)
    return X,y

# %%
X,y=window_data(scaled_data,8)

# %%
X
# Out:
# [array([[-0.02028642],
#         [-0.00254776],
#         [ 0.0364758 ],
#         [ 0.0506668 ],
#         [ 0.11807272],
#         [ 0.12871535],
#         [ 0.19612091],
#         [ 0.10388172]]), array([[-0.00254776],
#         [ 0.0364758 ],
#         [ 0.0506668 ],
#         [ 0.11807272],
#         [ 0.12871535],
#         [ 0.19612091],
#         [ 0.10388172],
#         [ 0.13935833]]), array([[0.0364758 ],
#         [0.0506668 ],
#         [0.11807272],
#         [0.12871535],
#         [0.19612091],
#         [0.10388172],
#         [0.13935833],
#         [0.23869249]]), array([[0.0506668 ],
#         [0.11807272],
#         [0.12871535],
#         [0.19612091],
#         [0.10388172],
#         [0.13935833],
#         [0.23869249],
#         [0.2103112 ]]), array([[0.11807272],
#         [0.12871535],
#         [0.19612091],
#         [0.10388172],
#         [0.13935833],
#         [0.23869249],
#         [0.2103112 ],
#         [0.36995631]]), array([[0.12871535],
#         [0.19612091],
#         [0.10388172],
#         [0.13935833],
#         [0.23869249],
#         [0.2103112 ],
#         [0.36995631],
#         [0.27771712]]), array([[0.19612091],
#         [0.10388172],
#         [0.13935833],
#         [0.23869249],
#         [0.2103112 ],
#         [0.36995631],
#         [0.27771712],
#         [0.28481244]]), array([[0.10388172],
#         [0.13935833],
#         [0.23869249],
#         [0.2103112 ],
#         [0.36995631],
#         [0.27771712],
#         [0.28481244],
#         [0.25997917]]), array([[0.13935833],
#         [0.23869249],
#         [0.2103112 ],
#         [0.36995631],
#         [0.27771712],
#         [0.28481244],
#         [0.25997917],
#         [0.0506668 ]]), array([[ 0.23869249],
#         [ 0.2103112 ],
#         [ 0.36995631],
#         [ 0.27771712],
#         [ 0.28481244],
#         [ 0.25997917],
#         [ 0.0506668 ],
#         [-0.03092905]]), array([[ 0.2103112 ],
#         [ 0.36995631],
#         [ 0.27771712],
#         [ 0.28481244],
#         [ 0.25997917],
#         [ 0.0506668 ],
#         [-0.03092905],
#         [-0.14445492]]), array([[ 0.36995631],
#         [ 0.27771712],
#         [ 0.28481244],
#         [ 0.25997917],
#         [ 0.0506668 ],
#         [-0.03092905],
#         [-0.14445492],
#         [-0.14800187]]), array([[ 0.27771712],
#         [ 0.28481244],
#         [ 0.25997917],
#         [ 0.0506668 ],
#         [-0.03092905],
#         [-0.14445492],
#         [-0.14800187],
#         [-0.11962058]]), array([[ 0.28481244],
#         [ 0.25997917],
#         [ 0.0506668 ],
#         [-0.03092905],
#         [-0.14445492],
#         [-0.14800187],
#         [-0.11962058],
#         [-0.20121749]]), array([[ 0.25997917],
#         [ 0.0506668 ],
#         [-0.03092905],
#         [-0.14445492],
#         [-0.14800187],
#         [-0.11962058],
#         [-0.20121749],
#         [-0.14445492]]), array([[ 0.0506668 ],
#         [-0.03092905],
#         [-0.14445492],
#         [-0.14800187],
#         [-0.11962058],
#         [-0.20121749],
#         [-0.14445492],
#         [-0.17993082]]), array([[-0.03092905],
#         [-0.14445492],
#         [-0.14800187],
#         [-0.11962058],
#         [-0.20121749],
#         [-0.14445492],
#         [-0.17993082],
#         [-0.10543029]]), array([[-0.14445492],
#         [-0.14800187],
#         [-0.11962058],
#         [-0.20121749],
#         [-0.14445492],
#         [-0.17993082],
#         [-0.10543029],
#         [-0.14090725]]), array([[-0.14800187],
#         [-0.11962058],
#         [-0.20121749],
#         [-0.14445492],
#         [-0.17993082],
#         [-0.10543029],
#         [-0.14090725],
#         [-0.2508844 ]]), array([[-0.11962058],
#         [-0.20121749],
#         [-0.14445492],
#         [-0.17993082],
#         [-0.10543029],
#         [-0.14090725],
#         [-0.2508844 ],
#         [ 0.0364758 ]]), array([[-0.20121749],
#         [-0.14445492],
#         [-0.17993082],
#         [-0.10543029],
#         [-0.14090725],
#         [-0.2508844 ],
#         [ 0.0364758 ],
#         [ 0.07550043]]), array([[-0.14445492],
#         [-0.17993082],
#         [-0.10543029],
#         [-0.14090725],
#         [-0.2508844 ],
#         [ 0.0364758 ],
#         [ 0.07550043],
#         [-0.13735924]]), array([[-0.17993082],
#         [-0.10543029],
#         [-0.14090725],
#         [-0.2508844 ],
#         [ 0.0364758 ],
#         [ 0.07550043],
#         [-0.13735924],
#         [-0.06995368]]), array([[-0.10543029],
#         [-0.14090725],
#         [-0.2508844 ],
#         [ 0.0364758 ],
#         [ 0.07550043],
#         [-0.13735924],
#         [-0.06995368],
#         [-0.03447671]]), array([[-0.14090725],
#         [-0.2508844 ],
#         [ 0.0364758 ],
#         [ 0.07550043],
#         [-0.13735924],
#         [-0.06995368],
#         [-0.03447671],
#         [ 0.11807272]]), array([[-0.2508844 ],
#         [ 0.0364758 ],
#         [ 0.07550043],
#         [-0.13735924],
#         [-0.06995368],
#         [-0.03447671],
#         [ 0.11807272],
#         [ 0.05421482]]), array([[ 0.0364758 ],
#         [ 0.07550043],
#         [-0.13735924],
#         [-0.06995368],
#         [-0.03447671],
#         [ 0.11807272],
#         [ 0.05421482],
#         [ 0.05421482]]), array([[ 0.07550043],
#         [-0.13735924],
#         [-0.06995368],
#         [-0.03447671],
#         [ 0.11807272],
#         [ 0.05421482],
#         [ 0.05421482],
#         [-0.00254776]]), array([[-0.13735924],
#         [-0.06995368],
#         [-0.03447671],
#         [ 0.11807272],
#         [ 0.05421482],
#         [ 0.05421482],
#         [-0.00254776],
#         [ 0.05776248]]), array([[-0.06995368],
#         [-0.03447671],
#         [ 0.11807272],
#         [ 0.05421482],
#         [ 0.05421482],
#         [-0.00254776],
#         [ 0.05776248],
#         [ 0.01164253]]), array([[-0.03447671],
#         [ 0.11807272],
#         [ 0.05421482],
#         [ 0.05421482],
#         [-0.00254776],
#         [ 0.05776248],
#         [ 0.01164253],
#         [-0.11252596]]), array([[ 0.11807272],
#         [ 0.05421482],
#         [ 0.05421482],
#         [-0.00254776],
#         [ 0.05776248],
#         [ 0.01164253],
#         [-0.11252596],
#         [-0.12671625]]), array([[ 0.05421482],
#         [ 0.05421482],
#         [-0.00254776],
#         [ 0.05776248],
#         [ 0.01164253],
#         [-0.11252596],
#         [-0.12671625],
#         [-0.10897795]]), array([[ 0.05421482],
#         [-0.00254776],
#         [ 0.05776248],
#         [ 0.01164253],
#         [-0.11252596],
#         [-0.12671625],
#         [-0.10897795],
#         [-0.11607363]]), array([[-0.00254776],
#         [ 0.05776248],
#         [ 0.01164253],
#         [-0.11252596],
#         [-0.12671625],
#         [-0.10897795],
#         [-0.11607363],
#         [ 0.12516733]]), array([[ 0.05776248],
#         [ 0.01164253],
#         [-0.11252596],
#         [-0.12671625],
#         [-0.10897795],
#         [-0.11607363],
#         [ 0.12516733],
#         [ 0.1748353 ]]), array([[ 0.01164253],
#         [-0.11252596],
#         [-0.12671625],
#         [-0.10897795],
#         [-0.11607363],
#         [ 0.12516733],
#         [ 0.1748353 ],
#         [ 0.18192991]]), array([[-0.11252596],
#         [-0.12671625],
#         [-0.10897795],
#         [-0.11607363],
#         [ 0.12516733],
#         [ 0.1748353 ],
#         [ 0.18192991],
#         [ 0.18192991]]), array([[-0.12671625],
#         [-0.10897795],
#         [-0.11607363],
#         [ 0.12516733],
#         [ 0.1748353 ],
#         [ 0.18192991],
#         [ 0.18192991],
#         [ 0.16773962]]), array([[-0.10897795],
#         [-0.11607363],
#         [ 0.12516733],
#         [ 0.1748353 ],
#         [ 0.18192991],
#         [ 0.18192991],
#         [ 0.16773962],
#         [ 0.19257325]]), array([[-0.11607363],
#         [ 0.12516733],
#         [ 0.1748353 ],
#         [ 0.18192991],
#         [ 0.18192991],
#         [ 0.16773962],
#         [ 0.19257325],
#         [ 0.36995631]]), array([[0.12516733],
#         [0.1748353 ],
#         [0.18192991],
#         [0.18192991],
#         [0.16773962],
#         [0.19257325],
#         [0.36995631],
#         [0.43026655]]), array([[0.1748353 ],
#         [0.18192991],
#         [0.18192991],
#         [0.16773962],
#         [0.19257325],
#         [0.36995631],
#         [0.43026655],
#         [0.51186276]]), array([[0.18192991],
#         [0.18192991],
#         [0.16773962],
#         [0.19257325],
#         [0.36995631],
#         [0.43026655],
#         [0.51186276],
#         [0.50831474]]), array([[0.18192991],
#         [0.16773962],
#         [0.19257325],
#         [0.36995631],
#         [0.43026655],
#         [0.51186276],
#         [0.50831474],
#         [0.48702913]]), array([[0.16773962],
#         [0.19257325],
#         [0.36995631],
#         [0.43026655],
#         [0.51186276],
#         [0.50831474],
#         [0.48702913],
#         [0.52605376]]), array([[0.19257325],
#         [0.36995631],
#         [0.43026655],
#         [0.51186276],
#         [0.50831474],
#         [0.48702913],
#         [0.52605376],
#         [0.49057679]]), array([[0.36995631],
#         [0.43026655],
#         [0.51186276],
#         [0.50831474],
#         [0.48702913],
#         [0.52605376],
#         [0.49057679],
#         [0.34157502]]), array([[0.43026655],
#         [0.51186276],
#         [0.50831474],
#         [0.48702913],
#         [0.52605376],
#         [0.49057679],
#         [0.34157502],
#         [0.41607555]]), array([[0.51186276],
#         [0.50831474],
#         [0.48702913],
#         [0.52605376],
#         [0.49057679],
#         [0.34157502],
#         [0.41607555],
#         [0.37350397]]), array([[0.50831474],
#         [0.48702913],
#         [0.52605376],
#         [0.49057679],
#         [0.34157502],
#         [0.41607555],
#         [0.37350397],
#         [0.32738402]]), array([[0.48702913],
#         [0.52605376],
#         [0.49057679],
#         [0.34157502],
#         [0.41607555],
#         [0.37350397],
#         [0.32738402],
#         [0.38769426]]), array([[0.52605376],
#         [0.49057679],
#         [0.34157502],
#         [0.41607555],
#         [0.37350397],
#         [0.32738402],
#         [0.38769426],
#         [0.38059965]]), array([[0.49057679],
#         [0.34157502],
#         [0.41607555],
#         [0.37350397],
#         [0.32738402],
#         [0.38769426],
#         [0.38059965],
#         [0.35576531]]), array([[0.34157502],
#         [0.41607555],
#         [0.37350397],
#         [0.32738402],
#         [0.38769426],
#         [0.38059965],
#         [0.35576531],
#         [0.33093168]]), array([[0.41607555],
#         [0.37350397],
#         [0.32738402],
#         [0.38769426],
#         [0.38059965],
#         [0.35576531],
#         [0.33093168],
#         [0.31674139]]), array([[0.37350397],
#         [0.32738402],
#         [0.38769426],
#         [0.38059965],
#         [0.35576531],
#         [0.33093168],
#         [0.31674139],
#         [0.20676425]]), array([[0.32738402],
#         [0.38769426],
#         [0.38059965],
#         [0.35576531],
#         [0.33093168],
#         [0.31674139],
#         [0.20676425],
#         [0.22804986]]), array([[0.38769426],
#         [0.38059965],
#         [0.35576531],
#         [0.33093168],
#         [0.31674139],
#         [0.20676425],
#         [0.22804986],
#         [0.13226301]]), array([[0.38059965],
#         [0.35576531],
#         [0.33093168],
#         [0.31674139],
#         [0.20676425],
#         [0.22804986],
#         [0.13226301],
#         [0.08969072]]), array([[0.35576531],
#         [0.33093168],
#         [0.31674139],
#         [0.20676425],
#         [0.22804986],
#         [0.13226301],
#         [0.08969072],
#         [0.13226301]]), array([[0.33093168],
#         [0.31674139],
#         [0.20676425],
#         [0.22804986],
#         [0.13226301],
#         [0.08969072],
#         [0.13226301],
#         [0.04002382]]), array([[0.31674139],
#         [0.20676425],
#         [0.22804986],
#         [0.13226301],
#         [0.08969072],
#         [0.13226301],
#         [0.04002382],
#         [0.07904809]]), array([[0.20676425],
#         [0.22804986],
#         [0.13226301],
#         [0.08969072],
#         [0.13226301],
#         [0.04002382],
#         [0.07904809],
#         [0.13581067]]), array([[0.22804986],
#         [0.13226301],
#         [0.08969072],
#         [0.13226301],
#         [0.04002382],
#         [0.07904809],
#         [0.13581067],
#         [0.1606443 ]]), array([[0.13226301],
#         [0.08969072],
#         [0.13226301],
#         [0.04002382],
#         [0.07904809],
#         [0.13581067],
#         [0.1606443 ],
#         [0.28126478]]), array([[0.08969072],
#         [0.13226301],
#         [0.04002382],
#         [0.07904809],
#         [0.13581067],
#         [0.1606443 ],
#         [0.28126478],
#         [0.19966857]]), array([[0.13226301],
#         [0.04002382],
#         [0.07904809],
#         [0.13581067],
#         [0.1606443 ],
#         [0.28126478],
#         [0.19966857],
#         [0.25288349]]), array([[0.04002382],
#         [0.07904809],
#         [0.13581067],
#         [0.1606443 ],
#         [0.28126478],
#         [0.19966857],
#         [0.25288349],
#         [0.15354862]]), array([[0.07904809],
#         [0.13581067],
#         [0.1606443 ],
#         [0.28126478],
#         [0.19966857],
#         [0.25288349],
#         [0.15354862],
#         [0.15709664]]), array([[0.13581067],
#         [0.1606443 ],
#         [0.28126478],
#         [0.19966857],
#         [0.25288349],
#         [0.15354862],
#         [0.15709664],
#         [0.13935833]]), array([[ 0.1606443 ],
#         [ 0.28126478],
#         [ 0.19966857],
#         [ 0.25288349],
#         [ 0.15354862],
#         [ 0.15709664],
#         [ 0.13935833],
#         [-0.09833497]]), array([[ 0.28126478],
#         [ 0.19966857],
#         [ 0.25288349],
#         [ 0.15354862],
#         [ 0.15709664],
#         [ 0.13935833],
#         [-0.09833497],
#         [-0.0273821 ]]), array([[ 0.19966857],
#         [ 0.25288349],
#         [ 0.15354862],
#         [ 0.15709664],
#         [ 0.13935833],
#         [-0.09833497],
#         [-0.0273821 ],
#         [-0.02028642]]), array([[ 0.25288349],
#         [ 0.15354862],
#         [ 0.15709664],
#         [ 0.13935833],
#         [-0.09833497],
#         [-0.0273821 ],
#         [-0.02028642],
#         [-0.06995368]]), array([[ 0.15354862],
#         [ 0.15709664],
#         [ 0.13935833],
#         [-0.09833497],
#         [-0.0273821 ],
#         [-0.02028642],
#         [-0.06995368],
#         [-0.00254776]]), array([[ 0.15709664],
#         [ 0.13935833],
#         [-0.09833497],
#         [-0.0273821 ],
#         [-0.02028642],
#         [-0.06995368],
#         [-0.00254776],
#         [-0.062858  ]]), array([[ 0.13935833],
#         [-0.09833497],
#         [-0.0273821 ],
#         [-0.02028642],
#         [-0.06995368],
#         [-0.00254776],
#         [-0.062858  ],
#         [-0.31829031]]), array([[-0.09833497],
#         [-0.0273821 ],
#         [-0.02028642],
#         [-0.06995368],
#         [-0.00254776],
#         [-0.062858  ],
#         [-0.31829031],
#         [-0.21540778]]), array([[-0.0273821 ],
#         [-0.02028642],
#         [-0.06995368],
#         [-0.00254776],
#         [-0.062858  ],
#         [-0.31829031],
#         [-0.21540778],
#         [-0.2366934 ]]), array([[-0.02028642],
#         [-0.06995368],
#         [-0.00254776],
#         [-0.062858  ],
#         [-0.31829031],
#         [-0.21540778],
#         [-0.2366934 ],
#         [-0.13026392]]), array([[-0.06995368],
#         [-0.00254776],
#         [-0.062858  ],
#         [-0.31829031],
#         [-0.21540778],
#         [-0.2366934 ],
#         [-0.13026392],
#         [-0.03802473]]), array([[-0.00254776],
#         [-0.062858  ],
#         [-0.31829031],
#         [-0.21540778],
#         [-0.2366934 ],
#         [-0.13026392],
#         [-0.03802473],
#         [-0.15154953]]), array([[-0.062858  ],
#         [-0.31829031],
#         [-0.21540778],
#         [-0.2366934 ],
#         [-0.13026392],
#         [-0.03802473],
#         [-0.15154953],
#         [-0.11607363]]), array([[-0.31829031],
#         [-0.21540778],
#         [-0.2366934 ],
#         [-0.13026392],
#         [-0.03802473],
#         [-0.15154953],
#         [-0.11607363],
#         [-0.10188263]]), array([[-0.21540778],
#         [-0.2366934 ],
#         [-0.13026392],
#         [-0.03802473],
#         [-0.15154953],
#         [-0.11607363],
#         [-0.10188263],
#         [-0.13381158]]), array([[-0.2366934 ],
#         [-0.13026392],
#         [-0.03802473],
#         [-0.15154953],
#         [-0.11607363],
#         [-0.10188263],
#         [-0.13381158],
#         [-0.09833497]]), array([[-0.13026392],
#         [-0.03802473],
#         [-0.15154953],
#         [-0.11607363],
#         [-0.10188263],
#         [-0.13381158],
#         [-0.09833497],
#         [ 0.19257325]]), array([[-0.03802473],
#         [-0.15154953],
#         [-0.11607363],
#         [-0.10188263],
#         [-0.13381158],
#         [-0.09833497],
#         [ 0.19257325],
#         [ 0.10388172]]), array([[-0.15154953],
#         [-0.11607363],
#         [-0.10188263],
#         [-0.13381158],
#         [-0.09833497],
#         [ 0.19257325],
#         [ 0.10388172],
#         [-0.04157239]]), array([[-0.11607363],
#         [-0.10188263],
#         [-0.13381158],
#         [-0.09833497],
#         [ 0.19257325],
#         [ 0.10388172],
#         [-0.04157239],
#         [-0.11252596]]), array([[-0.10188263],
#         [-0.13381158],
#         [-0.09833497],
#         [ 0.19257325],
#         [ 0.10388172],
#         [-0.04157239],
#         [-0.11252596],
#         [-0.20831211]]), array([[-0.13381158],
#         [-0.09833497],
#         [ 0.19257325],
#         [ 0.10388172],
#         [-0.04157239],
#         [-0.11252596],
#         [-0.20831211],
#         [-0.09478695]]), array([[-0.09833497],
#         [ 0.19257325],
#         [ 0.10388172],
#         [-0.04157239],
#         [-0.11252596],
#         [-0.20831211],
#         [-0.09478695],
#         [-0.11962058]]), array([[ 0.19257325],
#         [ 0.10388172],
#         [-0.04157239],
#         [-0.11252596],
#         [-0.20831211],
#         [-0.09478695],
#         [-0.11962058],
#         [ 0.02583353]]), array([[ 0.10388172],
#         [-0.04157239],
#         [-0.11252596],
#         [-0.20831211],
#         [-0.09478695],
#         [-0.11962058],
#         [ 0.02583353],
#         [-0.19057416]]), array([[-0.04157239],
#         [-0.11252596],
#         [-0.20831211],
#         [-0.09478695],
#         [-0.11962058],
#         [ 0.02583353],
#         [-0.19057416],
#         [-0.2508844 ]]), array([[-0.11252596],
#         [-0.20831211],
#         [-0.09478695],
#         [-0.11962058],
#         [ 0.02583353],
#         [-0.19057416],
#         [-0.2508844 ],
#         [-0.46374407]]), array([[-0.20831211],
#         [-0.09478695],
#         [-0.11962058],
#         [ 0.02583353],
#         [-0.19057416],
#         [-0.2508844 ],
#         [-0.46374407],
#         [-0.40698184]]), array([[-0.09478695],
#         [-0.11962058],
#         [ 0.02583353],
#         [-0.19057416],
#         [-0.2508844 ],
#         [-0.46374407],
#         [-0.40698184],
#         [-0.43536278]]), array([[-0.11962058],
#         [ 0.02583353],
#         [-0.19057416],
#         [-0.2508844 ],
#         [-0.46374407],
#         [-0.40698184],
#         [-0.43536278],
#         [-0.21895544]]), array([[ 0.02583353],
#         [-0.19057416],
#         [-0.2508844 ],
#         [-0.46374407],
#         [-0.40698184],
#         [-0.43536278],
#         [-0.21895544],
#         [-0.09833497]]), array([[-0.19057416],
#         [-0.2508844 ],
#         [-0.46374407],
#         [-0.40698184],
#         [-0.43536278],
#         [-0.21895544],
#         [-0.09833497],
#         [-0.17993082]]), array([[-0.2508844 ],
#         [-0.46374407],
#         [-0.40698184],
#         [-0.43536278],
#         [-0.21895544],
#         [-0.09833497],
#         [-0.17993082],
#         [-0.19057416]]), array([[-0.46374407],
#         [-0.40698184],
#         [-0.43536278],
#         [-0.21895544],
#         [-0.09833497],
#         [-0.17993082],
#         [-0.19057416],
#         [-0.19057416]]), array([[-0.40698184],
#         [-0.43536278],
#         [-0.21895544],
#         [-0.09833497],
#         [-0.17993082],
#         [-0.19057416],
#         [-0.19057416],
#         [-0.05576339]]), array([[-0.43536278],
#         [-0.21895544],
#         [-0.09833497],
#         [-0.17993082],
#         [-0.19057416],
#         [-0.19057416],
#         [-0.05576339],
#         [-0.077049  ]]), array([[-0.21895544],
#         [-0.09833497],
#         [-0.17993082],
#         [-0.19057416],
#         [-0.19057416],
#         [-0.05576339],
#         [-0.077049  ],
#         [-0.14800187]]), array([[-0.09833497],
#         [-0.17993082],
#         [-0.19057416],
#         [-0.19057416],
#         [-0.05576339],
#         [-0.077049  ],
#         [-0.14800187],
#         [-0.17993082]]), array([[-0.17993082],
#         [-0.19057416],
#         [-0.19057416],
#         [-0.05576339],
#         [-0.077049  ],
#         [-0.14800187],
#         [-0.17993082],
#         [-0.21895544]]), array([[-0.19057416],
#         [-0.19057416],
#         [-0.05576339],
#         [-0.077049  ],
#         [-0.14800187],
#         [-0.17993082],
#         [-0.21895544],
#         [-0.79722457]]), array([[-0.19057416],
#         [-0.05576339],
#         [-0.077049  ],
#         [-0.14800187],
#         [-0.17993082],
#         [-0.21895544],
#         [-0.79722457],
#         [-0.65531741]]), array([[-0.05576339],
#         [-0.077049  ],
#         [-0.14800187],
#         [-0.17993082],
#         [-0.21895544],
#         [-0.79722457],
#         [-0.65531741],
#         [-0.61274583]]), array([[-0.077049  ],
#         [-0.14800187],
#         [-0.17993082],
#         [-0.21895544],
#         [-0.79722457],
#         [-0.65531741],
#         [-0.61274583],
#         [-0.35376692]]), array([[-0.14800187],
#         [-0.17993082],
#         [-0.21895544],
#         [-0.79722457],
#         [-0.65531741],
#         [-0.61274583],
#         [-0.35376692],
#         [-0.25443206]]), array([[-0.17993082],
#         [-0.21895544],
#         [-0.79722457],
#         [-0.65531741],
#         [-0.61274583],
#         [-0.35376692],
#         [-0.25443206],
#         [-0.35731388]]), array([[-0.21895544],
#         [-0.79722457],
#         [-0.65531741],
#         [-0.61274583],
#         [-0.35376692],
#         [-0.25443206],
#         [-0.35731388],
#         [-0.70853304]]), array([[-0.79722457],
#         [-0.65531741],
#         [-0.61274583],
#         [-0.35376692],
#         [-0.25443206],
#         [-0.35731388],
#         [-0.70853304],
#         [-0.62693612]]), array([[-0.65531741],
#         [-0.61274583],
#         [-0.35376692],
#         [-0.25443206],
#         [-0.35731388],
#         [-0.70853304],
#         [-0.62693612],
#         [-0.5382446 ]]), array([[-0.61274583],
#         [-0.35376692],
#         [-0.25443206],
#         [-0.35731388],
#         [-0.70853304],
#         [-0.62693612],
#         [-0.5382446 ],
#         [-0.46729208]]), array([[-0.35376692],
#         [-0.25443206],
#         [-0.35731388],
#         [-0.70853304],
#         [-0.62693612],
#         [-0.5382446 ],
#         [-0.46729208],
#         [-0.33957592]]), array([[-0.25443206],
#         [-0.35731388],
#         [-0.70853304],
#         [-0.62693612],
#         [-0.5382446 ],
#         [-0.46729208],
#         [-0.33957592],
#         [-0.45310108]]), array([[-0.35731388],
#         [-0.70853304],
#         [-0.62693612],
#         [-0.5382446 ],
#         [-0.46729208],
#         [-0.33957592],
#         [-0.45310108],
#         [-0.47793436]]), array([[-0.70853304],
#         [-0.62693612],
#         [-0.5382446 ],
#         [-0.46729208],
#         [-0.33957592],
#         [-0.45310108],
#         [-0.47793436],
#         [-0.41762412]]), array([[-0.62693612],
#         [-0.5382446 ],
#         [-0.46729208],
#         [-0.33957592],
#         [-0.45310108],
#         [-0.47793436],
#         [-0.41762412],
#         [-0.54179261]]), array([[-0.5382446 ],
#         [-0.46729208],
#         [-0.33957592],
#         [-0.45310108],
#         [-0.47793436],
#         [-0.41762412],
#         [-0.54179261],
#         [-0.59855519]]), array([[-0.46729208],
#         [-0.33957592],
#         [-0.45310108],
#         [-0.47793436],
#         [-0.41762412],
#         [-0.54179261],
#         [-0.59855519],
#         [-0.63757946]]), array([[-0.33957592],
#         [-0.45310108],
#         [-0.47793436],
#         [-0.41762412],
#         [-0.54179261],
#         [-0.59855519],
#         [-0.63757946],
#         [-0.59500717]]), array([[-0.45310108],
#         [-0.47793436],
#         [-0.41762412],
#         [-0.54179261],
#         [-0.59855519],
#         [-0.63757946],
#         [-0.59500717],
#         [-0.82915281]]), array([[-0.47793436],
#         [-0.41762412],
#         [-0.54179261],
#         [-0.59855519],
#         [-0.63757946],
#         [-0.59500717],
#         [-0.82915281],
#         [-0.78658123]]), array([[-0.41762412],
#         [-0.54179261],
#         [-0.59855519],
#         [-0.63757946],
#         [-0.59500717],
#         [-0.82915281],
#         [-0.78658123],
#         [-0.90720171]]), array([[-0.54179261],
#         [-0.59855519],
#         [-0.63757946],
#         [-0.59500717],
#         [-0.82915281],
#         [-0.78658123],
#         [-0.90720171],
#         [-0.97460763]]), array([[-0.59855519],
#         [-0.63757946],
#         [-0.59500717],
#         [-0.82915281],
#         [-0.78658123],
#         [-0.90720171],
#         [-0.97460763],
#         [-1.03137021]]), array([[-0.63757946],
#         [-0.59500717],
#         [-0.82915281],
#         [-0.78658123],
#         [-0.90720171],
#         [-0.97460763],
#         [-1.03137021],
#         [-1.12360869]]), array([[-0.59500717],
#         [-0.82915281],
#         [-0.78658123],
#         [-0.90720171],
#         [-0.97460763],
#         [-1.03137021],
#         [-1.12360869],
#         [-1.16618098]]), array([[-0.82915281],
#         [-0.78658123],
#         [-0.90720171],
#         [-0.97460763],
#         [-1.03137021],
#         [-1.12360869],
#         [-1.16618098],
#         [-1.08813279]]), array([[-0.78658123],
#         [-0.90720171],
#         [-0.97460763],
#         [-1.03137021],
#         [-1.12360869],
#         [-1.16618098],
#         [-1.08813279],
#         [-0.83979615]]), array([[-0.90720171],
#         [-0.97460763],
#         [-1.03137021],
#         [-1.12360869],
#         [-1.16618098],
#         [-1.08813279],
#         [-0.83979615],
#         [-0.81851018]]), array([[-0.97460763],
#         [-1.03137021],
#         [-1.12360869],
#         [-1.16618098],
#         [-1.08813279],
#         [-0.83979615],
#         [-0.81851018],
#         [-0.83979615]]), array([[-1.03137021],
#         [-1.12360869],
#         [-1.16618098],
#         [-1.08813279],
#         [-0.83979615],
#         [-0.81851018],
#         [-0.83979615],
#         [-0.74755696]]), array([[-1.12360869],
#         [-1.16618098],
#         [-1.08813279],
#         [-0.83979615],
#         [-0.81851018],
#         [-0.83979615],
#         [-0.74755696],
#         [-0.96751195]]), array([[-1.16618098],
#         [-1.08813279],
#         [-0.83979615],
#         [-0.81851018],
#         [-0.83979615],
#         [-0.74755696],
#         [-0.96751195],
#         [-0.97815458]]), array([[-1.08813279],
#         [-0.83979615],
#         [-0.81851018],
#         [-0.83979615],
#         [-0.74755696],
#         [-0.96751195],
#         [-0.97815458],
#         [-0.97815458]]), array([[-0.83979615],
#         [-0.81851018],
#         [-0.83979615],
#         [-0.74755696],
#         [-0.96751195],
#         [-0.97815458],
#         [-0.97815458],
#         [-0.8859161 ]]), array([[-0.81851018],
#         [-0.83979615],
#         [-0.74755696],
#         [-0.96751195],
#         [-0.97815458],
#         [-0.97815458],
#         [-0.8859161 ],
#         [-0.80431918]]), array([[-0.83979615],
#         [-0.74755696],
#         [-0.96751195],
#         [-0.97815458],
#         [-0.97815458],
#         [-0.8859161 ],
#         [-0.80431918],
#         [-0.71562765]]), array([[-0.74755696],
#         [-0.96751195],
#         [-0.97815458],
#         [-0.97815458],
#         [-0.8859161 ],
#         [-0.80431918],
#         [-0.71562765],
#         [-0.6978897 ]]), array([[-0.96751195],
#         [-0.97815458],
#         [-0.97815458],
#         [-0.8859161 ],
#         [-0.80431918],
#         [-0.71562765],
#         [-0.6978897 ],
#         [-0.61984151]]), array([[-0.97815458],
#         [-0.97815458],
#         [-0.8859161 ],
#         [-0.80431918],
#         [-0.71562765],
#         [-0.6978897 ],
#         [-0.61984151],
#         [-0.72272333]]), array([[-0.97815458],
#         [-0.8859161 ],
#         [-0.80431918],
#         [-0.71562765],
#         [-0.6978897 ],
#         [-0.61984151],
#         [-0.72272333],
#         [-0.6836987 ]]), array([[-0.8859161 ],
#         [-0.80431918],
#         [-0.71562765],
#         [-0.6978897 ],
#         [-0.61984151],
#         [-0.72272333],
#         [-0.6836987 ],
#         [-0.60565051]]), array([[-0.80431918],
#         [-0.71562765],
#         [-0.6978897 ],
#         [-0.61984151],
#         [-0.72272333],
#         [-0.6836987 ],
#         [-0.60565051],
#         [-0.67305643]]), array([[-0.71562765],
#         [-0.6978897 ],
#         [-0.61984151],
#         [-0.72272333],
#         [-0.6836987 ],
#         [-0.60565051],
#         [-0.67305643],
#         [-0.75465228]]), array([[-0.6978897 ],
#         [-0.61984151],
#         [-0.72272333],
#         [-0.6836987 ],
#         [-0.60565051],
#         [-0.67305643],
#         [-0.75465228],
#         [-0.6978897 ]]), array([[-0.61984151],
#         [-0.72272333],
#         [-0.6836987 ],
#         [-0.60565051],
#         [-0.67305643],
#         [-0.75465228],
#         [-0.6978897 ],
#         [-0.74755696]]), array([[-0.72272333],
#         [-0.6836987 ],
#         [-0.60565051],
#         [-0.67305643],
#         [-0.75465228],
#         [-0.6978897 ],
#         [-0.74755696],
#         [-0.89655873]]), array([[-0.6836987 ],
#         [-0.60565051],
#         [-0.67305643],
#         [-0.75465228],
#         [-0.6978897 ],
#         [-0.74755696],
#         [-0.89655873],
#         [-0.61984151]]), array([[-0.60565051],
#         [-0.67305643],
#         [-0.75465228],
#         [-0.6978897 ],
#         [-0.74755696],
#         [-0.89655873],
#         [-0.61984151],
#         [-0.8575341 ]]), array([[-0.67305643],
#         [-0.75465228],
#         [-0.6978897 ],
#         [-0.74755696],
#         [-0.89655873],
#         [-0.61984151],
#         [-0.8575341 ],
#         [-0.86817744]]), array([[-0.75465228],
#         [-0.6978897 ],
#         [-0.74755696],
#         [-0.89655873],
#         [-0.61984151],
#         [-0.8575341 ],
#         [-0.86817744],
#         [-0.83624849]]), array([[-0.6978897 ],
#         [-0.74755696],
#         [-0.89655873],
#         [-0.61984151],
#         [-0.8575341 ],
#         [-0.86817744],
#         [-0.83624849],
#         [-0.8859161 ]]), array([[-0.74755696],
#         [-0.89655873],
#         [-0.61984151],
#         [-0.8575341 ],
#         [-0.86817744],
#         [-0.83624849],
#         [-0.8859161 ],
#         [-0.70143736]]), array([[-0.89655873],
#         [-0.61984151],
#         [-0.8575341 ],
#         [-0.86817744],
#         [-0.83624849],
#         [-0.8859161 ],
#         [-0.70143736],
#         [-0.36086154]]), array([[-0.61984151],
#         [-0.8575341 ],
#         [-0.86817744],
#         [-0.83624849],
#         [-0.8859161 ],
#         [-0.70143736],
#         [-0.36086154],
#         [ 0.06130943]]), array([[-0.8575341 ],
#         [-0.86817744],
#         [-0.83624849],
#         [-0.8859161 ],
#         [-0.70143736],
#         [-0.36086154],
#         [ 0.06130943],
#         [-0.21540778]]), array([[-0.86817744],
#         [-0.83624849],
#         [-0.8859161 ],
#         [-0.70143736],
#         [-0.36086154],
#         [ 0.06130943],
#         [-0.21540778],
#         [-0.17993082]]), array([[-0.83624849],
#         [-0.8859161 ],
#         [-0.70143736],
#         [-0.36086154],
#         [ 0.06130943],
#         [-0.21540778],
#         [-0.17993082],
#         [-0.05576339]]), array([[-0.8859161 ],
#         [-0.70143736],
#         [-0.36086154],
#         [ 0.06130943],
#         [-0.21540778],
#         [-0.17993082],
#         [-0.05576339],
#         [-0.28636101]]), array([[-0.70143736],
#         [-0.36086154],
#         [ 0.06130943],
#         [-0.21540778],
#         [-0.17993082],
#         [-0.05576339],
#         [-0.28636101],
#         [-0.11962058]]), array([[-0.36086154],
#         [ 0.06130943],
#         [-0.21540778],
#         [-0.17993082],
#         [-0.05576339],
#         [-0.28636101],
#         [-0.11962058],
#         [-0.08414468]]), array([[ 0.06130943],
#         [-0.21540778],
#         [-0.17993082],
#         [-0.05576339],
#         [-0.28636101],
#         [-0.11962058],
#         [-0.08414468],
#         [ 0.15709664]]), array([[-0.21540778],
#         [-0.17993082],
#         [-0.05576339],
#         [-0.28636101],
#         [-0.11962058],
#         [-0.08414468],
#         [ 0.15709664],
#         [ 0.32738402]]), array([[-0.17993082],
#         [-0.05576339],
#         [-0.28636101],
#         [-0.11962058],
#         [-0.08414468],
#         [ 0.15709664],
#         [ 0.32738402],
#         [-0.00254776]]), array([[-0.05576339],
#         [-0.28636101],
#         [-0.11962058],
#         [-0.08414468],
#         [ 0.15709664],
#         [ 0.32738402],
#         [-0.00254776],
#         [ 0.04711914]]), array([[-0.28636101],
#         [-0.11962058],
#         [-0.08414468],
#         [ 0.15709664],
#         [ 0.32738402],
#         [-0.00254776],
#         [ 0.04711914],
#         [ 0.19257325]]), array([[-0.11962058],
#         [-0.08414468],
#         [ 0.15709664],
#         [ 0.32738402],
#         [-0.00254776],
#         [ 0.04711914],
#         [ 0.19257325],
#         [ 0.32383707]]), array([[-0.08414468],
#         [ 0.15709664],
#         [ 0.32738402],
#         [-0.00254776],
#         [ 0.04711914],
#         [ 0.19257325],
#         [ 0.32383707],
#         [ 0.3486707 ]]), array([[ 0.15709664],
#         [ 0.32738402],
#         [-0.00254776],
#         [ 0.04711914],
#         [ 0.19257325],
#         [ 0.32383707],
#         [ 0.3486707 ],
#         [ 0.29545578]]), array([[ 0.32738402],
#         [-0.00254776],
#         [ 0.04711914],
#         [ 0.19257325],
#         [ 0.32383707],
#         [ 0.3486707 ],
#         [ 0.29545578],
#         [ 0.25997917]]), array([[-0.00254776],
#         [ 0.04711914],
#         [ 0.19257325],
#         [ 0.32383707],
#         [ 0.3486707 ],
#         [ 0.29545578],
#         [ 0.25997917],
#         [ 0.31319373]]), array([[0.04711914],
#         [0.19257325],
#         [0.32383707],
#         [0.3486707 ],
#         [0.29545578],
#         [0.25997917],
#         [0.31319373],
#         [0.56862498]]), array([[0.19257325],
#         [0.32383707],
#         [0.3486707 ],
#         [0.29545578],
#         [0.25997917],
#         [0.31319373],
#         [0.56862498],
#         [0.25288349]]), array([[0.32383707],
#         [0.3486707 ],
#         [0.29545578],
#         [0.25997917],
#         [0.31319373],
#         [0.56862498],
#         [0.25288349],
#         [0.57926832]]), array([[0.3486707 ],
#         [0.29545578],
#         [0.25997917],
#         [0.31319373],
#         [0.56862498],
#         [0.25288349],
#         [0.57926832],
#         [0.45155252]]), array([[0.29545578],
#         [0.25997917],
#         [0.31319373],
#         [0.56862498],
#         [0.25288349],
#         [0.57926832],
#         [0.45155252],
#         [0.2883601 ]]), array([[0.25997917],
#         [0.31319373],
#         [0.56862498],
#         [0.25288349],
#         [0.57926832],
#         [0.45155252],
#         [0.2883601 ],
#         [0.14290635]]), array([[0.31319373],
#         [0.56862498],
#         [0.25288349],
#         [0.57926832],
#         [0.45155252],
#         [0.2883601 ],
#         [0.14290635],
#         [0.11452506]]), array([[0.56862498],
#         [0.25288349],
#         [0.57926832],
#         [0.45155252],
#         [0.2883601 ],
#         [0.14290635],
#         [0.11452506],
#         [0.00099919]]), array([[0.25288349],
#         [0.57926832],
#         [0.45155252],
#         [0.2883601 ],
#         [0.14290635],
#         [0.11452506],
#         [0.00099919],
#         [0.10388172]]), array([[0.57926832],
#         [0.45155252],
#         [0.2883601 ],
#         [0.14290635],
#         [0.11452506],
#         [0.00099919],
#         [0.10388172],
#         [0.13581067]]), array([[0.45155252],
#         [0.2883601 ],
#         [0.14290635],
#         [0.11452506],
#         [0.00099919],
#         [0.10388172],
#         [0.13581067],
#         [0.16419196]]), array([[0.2883601 ],
#         [0.14290635],
#         [0.11452506],
#         [0.00099919],
#         [0.10388172],
#         [0.13581067],
#         [0.16419196],
#         [0.15354862]]), array([[0.14290635],
#         [0.11452506],
#         [0.00099919],
#         [0.10388172],
#         [0.13581067],
#         [0.16419196],
#         [0.15354862],
#         [0.14645401]]), array([[0.11452506],
#         [0.00099919],
#         [0.10388172],
#         [0.13581067],
#         [0.16419196],
#         [0.15354862],
#         [0.14645401],
#         [0.08969072]]), array([[0.00099919],
#         [0.10388172],
#         [0.13581067],
#         [0.16419196],
#         [0.15354862],
#         [0.14645401],
#         [0.08969072],
#         [0.12871535]]), array([[0.10388172],
#         [0.13581067],
#         [0.16419196],
#         [0.15354862],
#         [0.14645401],
#         [0.08969072],
#         [0.12871535],
#         [0.26352683]]), array([[0.13581067],
#         [0.16419196],
#         [0.15354862],
#         [0.14645401],
#         [0.08969072],
#         [0.12871535],
#         [0.26352683],
#         [0.15709664]]), array([[0.16419196],
#         [0.15354862],
#         [0.14645401],
#         [0.08969072],
#         [0.12871535],
#         [0.26352683],
#         [0.15709664],
#         [0.11097704]]), array([[0.15354862],
#         [0.14645401],
#         [0.08969072],
#         [0.12871535],
#         [0.26352683],
#         [0.15709664],
#         [0.11097704],
#         [0.25997917]]), array([[0.14645401],
#         [0.08969072],
#         [0.12871535],
#         [0.26352683],
#         [0.15709664],
#         [0.11097704],
#         [0.25997917],
#         [0.08259611]]), array([[0.08969072],
#         [0.12871535],
#         [0.26352683],
#         [0.15709664],
#         [0.11097704],
#         [0.25997917],
#         [0.08259611],
#         [0.0506668 ]]), array([[ 0.12871535],
#         [ 0.26352683],
#         [ 0.15709664],
#         [ 0.11097704],
#         [ 0.25997917],
#         [ 0.08259611],
#         [ 0.0506668 ],
#         [-0.18702649]]), array([[ 0.26352683],
#         [ 0.15709664],
#         [ 0.11097704],
#         [ 0.25997917],
#         [ 0.08259611],
#         [ 0.0506668 ],
#         [-0.18702649],
#         [-0.16574053]]), array([[ 0.15709664],
#         [ 0.11097704],
#         [ 0.25997917],
#         [ 0.08259611],
#         [ 0.0506668 ],
#         [-0.18702649],
#         [-0.16574053],
#         [-0.20831211]]), array([[ 0.11097704],
#         [ 0.25997917],
#         [ 0.08259611],
#         [ 0.0506668 ],
#         [-0.18702649],
#         [-0.16574053],
#         [-0.20831211],
#         [-0.40343383]]), array([[ 0.25997917],
#         [ 0.08259611],
#         [ 0.0506668 ],
#         [-0.18702649],
#         [-0.16574053],
#         [-0.20831211],
#         [-0.40343383],
#         [-0.48503003]]), array([[ 0.08259611],
#         [ 0.0506668 ],
#         [-0.18702649],
#         [-0.16574053],
#         [-0.20831211],
#         [-0.40343383],
#         [-0.48503003],
#         [-0.53114998]]), array([[ 0.0506668 ],
#         [-0.18702649],
#         [-0.16574053],
#         [-0.20831211],
#         [-0.40343383],
#         [-0.48503003],
#         [-0.53114998],
#         [-0.48857769]]), array([[-0.18702649],
#         [-0.16574053],
#         [-0.20831211],
#         [-0.40343383],
#         [-0.48503003],
#         [-0.53114998],
#         [-0.48857769],
#         [-0.61984151]]), array([[-0.16574053],
#         [-0.20831211],
#         [-0.40343383],
#         [-0.48503003],
#         [-0.53114998],
#         [-0.48857769],
#         [-0.61984151],
#         [-0.51695898]]), array([[-0.20831211],
#         [-0.40343383],
#         [-0.48503003],
#         [-0.53114998],
#         [-0.48857769],
#         [-0.61984151],
#         [-0.51695898],
#         [-0.62338846]]), array([[-0.40343383],
#         [-0.48503003],
#         [-0.53114998],
#         [-0.48857769],
#         [-0.61984151],
#         [-0.51695898],
#         [-0.62338846],
#         [-0.71562765]]), array([[-0.48503003],
#         [-0.53114998],
#         [-0.48857769],
#         [-0.61984151],
#         [-0.51695898],
#         [-0.62338846],
#         [-0.71562765],
#         [-0.5701739 ]]), array([[-0.53114998],
#         [-0.48857769],
#         [-0.61984151],
#         [-0.51695898],
#         [-0.62338846],
#         [-0.71562765],
#         [-0.5701739 ],
#         [-0.67660409]]), array([[-0.48857769],
#         [-0.61984151],
#         [-0.51695898],
#         [-0.62338846],
#         [-0.71562765],
#         [-0.5701739 ],
#         [-0.67660409],
#         [-0.65176975]]), array([[-0.61984151],
#         [-0.51695898],
#         [-0.62338846],
#         [-0.71562765],
#         [-0.5701739 ],
#         [-0.67660409],
#         [-0.65176975],
#         [-0.6978897 ]]), array([[-0.51695898],
#         [-0.62338846],
#         [-0.71562765],
#         [-0.5701739 ],
#         [-0.67660409],
#         [-0.65176975],
#         [-0.6978897 ],
#         [-0.6978897 ]]), array([[-0.62338846],
#         [-0.71562765],
#         [-0.5701739 ],
#         [-0.67660409],
#         [-0.65176975],
#         [-0.6978897 ],
#         [-0.6978897 ],
#         [-0.72627099]]), array([[-0.71562765],
#         [-0.5701739 ],
#         [-0.67660409],
#         [-0.65176975],
#         [-0.6978897 ],
#         [-0.6978897 ],
#         [-0.72627099],
#         [-0.66596075]]), array([[-0.5701739 ],
#         [-0.67660409],
#         [-0.65176975],
#         [-0.6978897 ],
#         [-0.6978897 ],
#         [-0.72627099],
#         [-0.66596075],
#         [-0.62693612]]), array([[-0.67660409],
#         [-0.65176975],
#         [-0.6978897 ],
#         [-0.6978897 ],
#         [-0.72627099],
#         [-0.66596075],
#         [-0.62693612],
#         [-0.52405431]]), array([[-0.65176975],
#         [-0.6978897 ],
#         [-0.6978897 ],
#         [-0.72627099],
#         [-0.66596075],
#         [-0.62693612],
#         [-0.52405431],
#         [-0.66596075]]), array([[-0.6978897 ],
#         [-0.6978897 ],
#         [-0.72627099],
#         [-0.66596075],
#         [-0.62693612],
#         [-0.52405431],
#         [-0.66596075],
#         [-0.69434204]]), array([[-0.6978897 ],
#         [-0.72627099],
#         [-0.66596075],
#         [-0.62693612],
#         [-0.52405431],
#         [-0.66596075],
#         [-0.69434204],
#         [-0.93913102]]), array([[-0.72627099],
#         [-0.66596075],
#         [-0.62693612],
#         [-0.52405431],
#         [-0.66596075],
#         [-0.69434204],
#         [-0.93913102],
#         [-1.08458477]]), array([[-0.66596075],
#         [-0.62693612],
#         [-0.52405431],
#         [-0.66596075],
#         [-0.69434204],
#         [-0.93913102],
#         [-1.08458477],
#         [-1.08458477]]), array([[-0.62693612],
#         [-0.52405431],
#         [-0.66596075],
#         [-0.69434204],
#         [-0.93913102],
#         [-1.08458477],
#         [-1.08458477],
#         [-1.16972864]]), array([[-0.52405431],
#         [-0.66596075],
#         [-0.69434204],
#         [-0.93913102],
#         [-1.08458477],
#         [-1.08458477],
#         [-1.16972864],
#         [-1.25487251]]), array([[-0.66596075],
#         [-0.69434204],
#         [-0.93913102],
#         [-1.08458477],
#         [-1.08458477],
#         [-1.16972864],
#         [-1.25487251],
#         [-1.13779969]]), array([[-0.69434204],
#         [-0.93913102],
#         [-1.08458477],
#         [-1.08458477],
#         [-1.16972864],
#         [-1.25487251],
#         [-1.13779969],
#         [-1.25842017]]), array([[-0.93913102],
#         [-1.08458477],
#         [-1.08458477],
#         [-1.16972864],
#         [-1.25487251],
#         [-1.13779969],
#         [-1.25842017],
#         [-1.1910146 ]]), array([[-1.08458477],
#         [-1.08458477],
#         [-1.16972864],
#         [-1.25487251],
#         [-1.13779969],
#         [-1.25842017],
#         [-1.1910146 ],
#         [-1.06329916]]), array([[-1.08458477],
#         [-1.16972864],
#         [-1.25487251],
#         [-1.13779969],
#         [-1.25842017],
#         [-1.1910146 ],
#         [-1.06329916],
#         [-1.2052056 ]]), array([[-1.16972864],
#         [-1.25487251],
#         [-1.13779969],
#         [-1.25842017],
#         [-1.1910146 ],
#         [-1.06329916],
#         [-1.2052056 ],
#         [-1.02427453]]), array([[-1.25487251],
#         [-1.13779969],
#         [-1.25842017],
#         [-1.1910146 ],
#         [-1.06329916],
#         [-1.2052056 ],
#         [-1.02427453],
#         [-1.1094184 ]]), array([[-1.13779969],
#         [-1.25842017],
#         [-1.1910146 ],
#         [-1.06329916],
#         [-1.2052056 ],
#         [-1.02427453],
#         [-1.1094184 ],
#         [-1.38258866]]), array([[-1.25842017],
#         [-1.1910146 ],
#         [-1.06329916],
#         [-1.2052056 ],
#         [-1.02427453],
#         [-1.1094184 ],
#         [-1.38258866],
#         [-1.37549299]]), array([[-1.1910146 ],
#         [-1.06329916],
#         [-1.2052056 ],
#         [-1.02427453],
#         [-1.1094184 ],
#         [-1.38258866],
#         [-1.37549299],
#         [-1.06684611]]), array([[-1.06329916],
#         [-1.2052056 ],
#         [-1.02427453],
#         [-1.1094184 ],
#         [-1.38258866],
#         [-1.37549299],
#         [-1.06684611],
#         [-1.1590853 ]]), array([[-1.2052056 ],
#         [-1.02427453],
#         [-1.1094184 ],
#         [-1.38258866],
#         [-1.37549299],
#         [-1.06684611],
#         [-1.1590853 ],
#         [-1.18746659]]), array([[-1.02427453],
#         [-1.1094184 ],
#         [-1.38258866],
#         [-1.37549299],
#         [-1.06684611],
#         [-1.1590853 ],
#         [-1.18746659],
#         [-1.15199069]]), array([[-1.1094184 ],
#         [-1.38258866],
#         [-1.37549299],
#         [-1.06684611],
#         [-1.1590853 ],
#         [-1.18746659],
#         [-1.15199069],
#         [-1.1094184 ]]), array([[-1.38258866],
#         [-1.37549299],
#         [-1.06684611],
#         [-1.1590853 ],
#         [-1.18746659],
#         [-1.15199069],
#         [-1.1094184 ],
#         [-1.12715635]]), array([[-1.37549299],
#         [-1.06684611],
#         [-1.1590853 ],
#         [-1.18746659],
#         [-1.15199069],
#         [-1.1094184 ],
#         [-1.12715635],
#         [-1.12006174]]), array([[-1.06684611],
#         [-1.1590853 ],
#         [-1.18746659],
#         [-1.15199069],
#         [-1.1094184 ],
#         [-1.12715635],
#         [-1.12006174],
#         [-1.20165759]]), array([[-1.1590853 ],
#         [-1.18746659],
#         [-1.15199069],
#         [-1.1094184 ],
#         [-1.12715635],
#         [-1.12006174],
#         [-1.20165759],
#         [-1.29034912]]), array([[-1.18746659],
#         [-1.15199069],
#         [-1.1094184 ],
#         [-1.12715635],
#         [-1.12006174],
#         [-1.20165759],
#         [-1.29034912],
#         [-1.20875327]]), array([[-1.15199069],
#         [-1.1094184 ],
#         [-1.12715635],
#         [-1.12006174],
#         [-1.20165759],
#         [-1.29034912],
#         [-1.20875327],
#         [-1.25842017]]), array([[-1.1094184 ],
#         [-1.12715635],
#         [-1.12006174],
#         [-1.20165759],
#         [-1.29034912],
#         [-1.20875327],
#         [-1.25842017],
#         [-1.12006174]]), array([[-1.12715635],
#         [-1.12006174],
#         [-1.20165759],
#         [-1.29034912],
#         [-1.20875327],
#         [-1.25842017],
#         [-1.12006174],
#         [-1.19456227]]), array([[-1.12006174],
#         [-1.20165759],
#         [-1.29034912],
#         [-1.20875327],
#         [-1.25842017],
#         [-1.12006174],
#         [-1.19456227],
#         [-1.27970613]]), array([[-1.20165759],
#         [-1.29034912],
#         [-1.20875327],
#         [-1.25842017],
#         [-1.12006174],
#         [-1.19456227],
#         [-1.27970613],
#         [-1.24777683]]), array([[-1.29034912],
#         [-1.20875327],
#         [-1.25842017],
#         [-1.12006174],
#         [-1.19456227],
#         [-1.27970613],
#         [-1.24777683],
#         [-1.23713455]]), array([[-1.20875327],
#         [-1.25842017],
#         [-1.12006174],
#         [-1.19456227],
#         [-1.27970613],
#         [-1.24777683],
#         [-1.23713455],
#         [-1.0597515 ]]), array([[-1.25842017],
#         [-1.12006174],
#         [-1.19456227],
#         [-1.27970613],
#         [-1.24777683],
#         [-1.23713455],
#         [-1.0597515 ],
#         [-1.0455605 ]]), array([[-1.12006174],
#         [-1.19456227],
#         [-1.27970613],
#         [-1.24777683],
#         [-1.23713455],
#         [-1.0597515 ],
#         [-1.0455605 ],
#         [-1.0952274 ]]), array([[-1.19456227],
#         [-1.27970613],
#         [-1.24777683],
#         [-1.23713455],
#         [-1.0597515 ],
#         [-1.0455605 ],
#         [-1.0952274 ],
#         [-1.13425203]]), array([[-1.27970613],
#         [-1.24777683],
#         [-1.23713455],
#         [-1.0597515 ],
#         [-1.0455605 ],
#         [-1.0952274 ],
#         [-1.13425203],
#         [-1.16618098]]), array([[-1.24777683],
#         [-1.23713455],
#         [-1.0597515 ],
#         [-1.0455605 ],
#         [-1.0952274 ],
#         [-1.13425203],
#         [-1.16618098],
#         [-1.12006174]]), array([[-1.23713455],
#         [-1.0597515 ],
#         [-1.0455605 ],
#         [-1.0952274 ],
#         [-1.13425203],
#         [-1.16618098],
#         [-1.12006174],
#         [-0.99234558]]), array([[-1.0597515 ],
#         [-1.0455605 ],
#         [-1.0952274 ],
#         [-1.13425203],
#         [-1.16618098],
#         [-1.12006174],
#         [-0.99234558],
#         [-0.92848768]]), array([[-1.0455605 ],
#         [-1.0952274 ],
#         [-1.13425203],
#         [-1.16618098],
#         [-1.12006174],
#         [-0.99234558],
#         [-0.92848768],
# ...
#         [-1.69833015],
#         [-1.79766502],
#         [-1.80475963]]), array([[-1.47482785],
#         [-1.60254295],
#         [-1.70187781],
#         [-1.64511523],
#         [-1.69833015],
#         [-1.79766502],
#         [-1.80475963],
#         [-1.73735478]]), array([[-1.60254295],
#         [-1.70187781],
#         [-1.64511523],
#         [-1.69833015],
#         [-1.79766502],
#         [-1.80475963],
#         [-1.73735478],
#         [-3.18834784]]), array([[-1.70187781],
#         [-1.64511523],
#         [-1.69833015],
#         [-1.79766502],
#         [-1.80475963],
#         [-1.73735478],
#         [-3.18834784],
#         [-3.05708438]]), array([[-1.64511523],
#         [-1.69833015],
#         [-1.79766502],
#         [-1.80475963],
#         [-1.73735478],
#         [-3.18834784],
#         [-3.05708438],
#         [-2.91872559]]), array([[-1.69833015],
#         [-1.79766502],
#         [-1.80475963],
#         [-1.73735478],
#         [-3.18834784],
#         [-3.05708438],
#         [-2.91872559],
#         [-2.78036645]]), array([[-1.79766502],
#         [-1.80475963],
#         [-1.73735478],
#         [-3.18834784],
#         [-3.05708438],
#         [-2.91872559],
#         [-2.78036645],
#         [-2.74843821]]), array([[-1.80475963],
#         [-1.73735478],
#         [-3.18834784],
#         [-3.05708438],
#         [-2.91872559],
#         [-2.78036645],
#         [-2.74843821],
#         [-2.46462496]]), array([[-1.73735478],
#         [-3.18834784],
#         [-3.05708438],
#         [-2.91872559],
#         [-2.78036645],
#         [-2.74843821],
#         [-2.46462496],
#         [-2.39721905]]), array([[-3.18834784],
#         [-3.05708438],
#         [-2.91872559],
#         [-2.78036645],
#         [-2.74843821],
#         [-2.46462496],
#         [-2.39721905],
#         [-2.45043467]]), array([[-3.05708438],
#         [-2.91872559],
#         [-2.78036645],
#         [-2.74843821],
#         [-2.46462496],
#         [-2.39721905],
#         [-2.45043467],
#         [-2.49655391]]), array([[-2.91872559],
#         [-2.78036645],
#         [-2.74843821],
#         [-2.46462496],
#         [-2.39721905],
#         [-2.45043467],
#         [-2.49655391],
#         [-2.72005621]]), array([[-2.78036645],
#         [-2.74843821],
#         [-2.46462496],
#         [-2.39721905],
#         [-2.45043467],
#         [-2.49655391],
#         [-2.72005621],
#         [-2.65265101]]), array([[-2.74843821],
#         [-2.46462496],
#         [-2.39721905],
#         [-2.45043467],
#         [-2.49655391],
#         [-2.72005621],
#         [-2.65265101],
#         [-2.60653106]]), array([[-2.46462496],
#         [-2.39721905],
#         [-2.45043467],
#         [-2.49655391],
#         [-2.72005621],
#         [-2.65265101],
#         [-2.60653106],
#         [-2.77327184]]), array([[-2.39721905],
#         [-2.45043467],
#         [-2.49655391],
#         [-2.72005621],
#         [-2.65265101],
#         [-2.60653106],
#         [-2.77327184],
#         [-2.94001156]]), array([[-2.45043467],
#         [-2.49655391],
#         [-2.72005621],
#         [-2.65265101],
#         [-2.60653106],
#         [-2.77327184],
#         [-2.94001156],
#         [-2.67748463]]), array([[-2.49655391],
#         [-2.72005621],
#         [-2.65265101],
#         [-2.60653106],
#         [-2.77327184],
#         [-2.94001156],
#         [-2.67748463],
#         [-2.76972382]]), array([[-2.72005621],
#         [-2.65265101],
#         [-2.60653106],
#         [-2.77327184],
#         [-2.94001156],
#         [-2.67748463],
#         [-2.76972382],
#         [-2.69522259]]), array([[-2.65265101],
#         [-2.60653106],
#         [-2.77327184],
#         [-2.94001156],
#         [-2.67748463],
#         [-2.76972382],
#         [-2.69522259],
#         [-2.74489055]]), array([[-2.60653106],
#         [-2.77327184],
#         [-2.94001156],
#         [-2.67748463],
#         [-2.76972382],
#         [-2.69522259],
#         [-2.74489055],
#         [-2.64555568]]), array([[-2.77327184],
#         [-2.94001156],
#         [-2.67748463],
#         [-2.76972382],
#         [-2.69522259],
#         [-2.74489055],
#         [-2.64555568],
#         [-2.54267316]]), array([[-2.94001156],
#         [-2.67748463],
#         [-2.76972382],
#         [-2.69522259],
#         [-2.74489055],
#         [-2.64555568],
#         [-2.54267316],
#         [-2.45398163]]), array([[-2.67748463],
#         [-2.76972382],
#         [-2.69522259],
#         [-2.74489055],
#         [-2.64555568],
#         [-2.54267316],
#         [-2.45398163],
#         [-2.40076671]]), array([[-2.76972382],
#         [-2.69522259],
#         [-2.74489055],
#         [-2.64555568],
#         [-2.54267316],
#         [-2.45398163],
#         [-2.40076671],
#         [-2.64200802]]), array([[-2.69522259],
#         [-2.74489055],
#         [-2.64555568],
#         [-2.54267316],
#         [-2.45398163],
#         [-2.40076671],
#         [-2.64200802],
#         [-2.65974668]]), array([[-2.74489055],
#         [-2.64555568],
#         [-2.54267316],
#         [-2.45398163],
#         [-2.40076671],
#         [-2.64200802],
#         [-2.65974668],
#         [-2.80874774]]), array([[-2.64555568],
#         [-2.54267316],
#         [-2.45398163],
#         [-2.40076671],
#         [-2.64200802],
#         [-2.65974668],
#         [-2.80874774],
#         [-2.78391411]]), array([[-2.54267316],
#         [-2.45398163],
#         [-2.40076671],
#         [-2.64200802],
#         [-2.65974668],
#         [-2.80874774],
#         [-2.78391411],
#         [-2.80165313]]), array([[-2.45398163],
#         [-2.40076671],
#         [-2.64200802],
#         [-2.65974668],
#         [-2.80874774],
#         [-2.78391411],
#         [-2.80165313],
#         [-2.67748463]]), array([[-2.40076671],
#         [-2.64200802],
#         [-2.65974668],
#         [-2.80874774],
#         [-2.78391411],
#         [-2.80165313],
#         [-2.67748463],
#         [-2.90453495]]), array([[-2.64200802],
#         [-2.65974668],
#         [-2.80874774],
#         [-2.78391411],
#         [-2.80165313],
#         [-2.67748463],
#         [-2.90453495],
#         [-3.01096478]]), array([[-2.65974668],
#         [-2.80874774],
#         [-2.78391411],
#         [-2.80165313],
#         [-2.67748463],
#         [-2.90453495],
#         [-3.01096478],
#         [-3.25930107]]), array([[-2.80874774],
#         [-2.78391411],
#         [-2.80165313],
#         [-2.67748463],
#         [-2.90453495],
#         [-3.01096478],
#         [-3.25930107],
#         [-3.22737212]]), array([[-2.78391411],
#         [-2.80165313],
#         [-2.67748463],
#         [-2.90453495],
#         [-3.01096478],
#         [-3.25930107],
#         [-3.22737212],
#         [-3.21672913]]), array([[-2.80165313],
#         [-2.67748463],
#         [-2.90453495],
#         [-3.01096478],
#         [-3.25930107],
#         [-3.22737212],
#         [-3.21672913],
#         [-3.26284873]]), array([[-2.67748463],
#         [-2.90453495],
#         [-3.01096478],
#         [-3.25930107],
#         [-3.22737212],
#         [-3.21672913],
#         [-3.26284873],
#         [-3.28058703]]), array([[-2.90453495],
#         [-3.01096478],
#         [-3.25930107],
#         [-3.22737212],
#         [-3.21672913],
#         [-3.26284873],
#         [-3.28058703],
#         [-3.35508792]]), array([[-3.01096478],
#         [-3.25930107],
#         [-3.22737212],
#         [-3.21672913],
#         [-3.26284873],
#         [-3.28058703],
#         [-3.35508792],
#         [-3.13158526]]), array([[-3.25930107],
#         [-3.22737212],
#         [-3.21672913],
#         [-3.26284873],
#         [-3.28058703],
#         [-3.35508792],
#         [-3.13158526],
#         [-3.06063204]]), array([[-3.22737212],
#         [-3.21672913],
#         [-3.26284873],
#         [-3.28058703],
#         [-3.35508792],
#         [-3.13158526],
#         [-3.06063204],
#         [-2.96129753]]), array([[-3.21672913],
#         [-3.26284873],
#         [-3.28058703],
#         [-3.35508792],
#         [-3.13158526],
#         [-3.06063204],
#         [-2.96129753],
#         [-3.0003218 ]]), array([[-3.26284873],
#         [-3.28058703],
#         [-3.35508792],
#         [-3.13158526],
#         [-3.06063204],
#         [-2.96129753],
#         [-3.0003218 ],
#         [-2.96839285]]), array([[-3.28058703],
#         [-3.35508792],
#         [-3.13158526],
#         [-3.06063204],
#         [-2.96129753],
#         [-3.0003218 ],
#         [-2.96839285],
#         [-3.03934607]]), array([[-3.35508792],
#         [-3.13158526],
#         [-3.06063204],
#         [-2.96129753],
#         [-3.0003218 ],
#         [-2.96839285],
#         [-3.03934607],
#         [-2.84422471]]), array([[-3.13158526],
#         [-3.06063204],
#         [-2.96129753],
#         [-3.0003218 ],
#         [-2.96839285],
#         [-3.03934607],
#         [-2.84422471],
#         [-2.7768195 ]]), array([[-3.06063204],
#         [-2.96129753],
#         [-3.0003218 ],
#         [-2.96839285],
#         [-3.03934607],
#         [-2.84422471],
#         [-2.7768195 ],
#         [-2.64910334]]), array([[-2.96129753],
#         [-3.0003218 ],
#         [-2.96839285],
#         [-3.03934607],
#         [-2.84422471],
#         [-2.7768195 ],
#         [-2.64910334],
#         [-2.61717439]]), array([[-3.0003218 ],
#         [-2.96839285],
#         [-3.03934607],
#         [-2.84422471],
#         [-2.7768195 ],
#         [-2.64910334],
#         [-2.61717439],
#         [-2.59588878]]), array([[-2.96839285],
#         [-3.03934607],
#         [-2.84422471],
#         [-2.7768195 ],
#         [-2.64910334],
#         [-2.61717439],
#         [-2.59588878],
#         [-2.47526795]]), array([[-3.03934607],
#         [-2.84422471],
#         [-2.7768195 ],
#         [-2.64910334],
#         [-2.61717439],
#         [-2.59588878],
#         [-2.47526795],
#         [-2.51783953]]), array([[-2.84422471],
#         [-2.7768195 ],
#         [-2.64910334],
#         [-2.61717439],
#         [-2.59588878],
#         [-2.47526795],
#         [-2.51783953],
#         [-2.47172029]]), array([[-2.7768195 ],
#         [-2.64910334],
#         [-2.61717439],
#         [-2.59588878],
#         [-2.47526795],
#         [-2.51783953],
#         [-2.47172029],
#         [-2.46817263]]), array([[-2.64910334],
#         [-2.61717439],
#         [-2.59588878],
#         [-2.47526795],
#         [-2.51783953],
#         [-2.47172029],
#         [-2.46817263],
#         [-1.6664012 ]]), array([[-2.61717439],
#         [-2.59588878],
#         [-2.47526795],
#         [-2.51783953],
#         [-2.47172029],
#         [-2.46817263],
#         [-1.6664012 ],
#         [-1.53513809]]), array([[-2.59588878],
#         [-2.47526795],
#         [-2.51783953],
#         [-2.47172029],
#         [-2.46817263],
#         [-1.6664012 ],
#         [-1.53513809],
#         [-1.51739943]]), array([[-2.47526795],
#         [-2.51783953],
#         [-2.47172029],
#         [-2.46817263],
#         [-1.6664012 ],
#         [-1.53513809],
#         [-1.51739943],
#         [-1.52449475]]), array([[-2.51783953],
#         [-2.47172029],
#         [-2.46817263],
#         [-1.6664012 ],
#         [-1.53513809],
#         [-1.51739943],
#         [-1.52449475],
#         [-1.4925658 ]]), array([[-2.47172029],
#         [-2.46817263],
#         [-1.6664012 ],
#         [-1.53513809],
#         [-1.51739943],
#         [-1.52449475],
#         [-1.4925658 ],
#         [-1.60609096]]), array([[-2.46817263],
#         [-1.6664012 ],
#         [-1.53513809],
#         [-1.51739943],
#         [-1.52449475],
#         [-1.4925658 ],
#         [-1.60609096],
#         [-1.51739943]]), array([[-1.6664012 ],
#         [-1.53513809],
#         [-1.51739943],
#         [-1.52449475],
#         [-1.4925658 ],
#         [-1.60609096],
#         [-1.51739943],
#         [-1.5067568 ]]), array([[-1.53513809],
#         [-1.51739943],
#         [-1.52449475],
#         [-1.4925658 ],
#         [-1.60609096],
#         [-1.51739943],
#         [-1.5067568 ],
#         [-1.54223271]]), array([[-1.51739943],
#         [-1.52449475],
#         [-1.4925658 ],
#         [-1.60609096],
#         [-1.51739943],
#         [-1.5067568 ],
#         [-1.54223271],
#         [-1.59899528]]), array([[-1.52449475],
#         [-1.4925658 ],
#         [-1.60609096],
#         [-1.51739943],
#         [-1.5067568 ],
#         [-1.54223271],
#         [-1.59899528],
#         [-1.5067568 ]]), array([[-1.4925658 ],
#         [-1.60609096],
#         [-1.51739943],
#         [-1.5067568 ],
#         [-1.54223271],
#         [-1.59899528],
#         [-1.5067568 ],
#         [-1.49611347]]), array([[-1.60609096],
#         [-1.51739943],
#         [-1.5067568 ],
#         [-1.54223271],
#         [-1.59899528],
#         [-1.5067568 ],
#         [-1.49611347],
#         [-1.4925658 ]]), array([[-1.51739943],
#         [-1.5067568 ],
#         [-1.54223271],
#         [-1.59899528],
#         [-1.5067568 ],
#         [-1.49611347],
#         [-1.4925658 ],
#         [-1.61318628]]), array([[-1.5067568 ],
#         [-1.54223271],
#         [-1.59899528],
#         [-1.5067568 ],
#         [-1.49611347],
#         [-1.4925658 ],
#         [-1.61318628],
#         [-1.65575786]]), array([[-1.54223271],
#         [-1.59899528],
#         [-1.5067568 ],
#         [-1.49611347],
#         [-1.4925658 ],
#         [-1.61318628],
#         [-1.65575786],
#         [-1.85087958]]), array([[-1.59899528],
#         [-1.5067568 ],
#         [-1.49611347],
#         [-1.4925658 ],
#         [-1.61318628],
#         [-1.65575786],
#         [-1.85087958],
#         [-1.78702168]]), array([[-1.5067568 ],
#         [-1.49611347],
#         [-1.4925658 ],
#         [-1.61318628],
#         [-1.65575786],
#         [-1.85087958],
#         [-1.78702168],
#         [-1.62382962]]), array([[-1.49611347],
#         [-1.4925658 ],
#         [-1.61318628],
#         [-1.65575786],
#         [-1.85087958],
#         [-1.78702168],
#         [-1.62382962],
#         [-1.61318628]]), array([[-1.4925658 ],
#         [-1.61318628],
#         [-1.65575786],
#         [-1.85087958],
#         [-1.78702168],
#         [-1.62382962],
#         [-1.61318628],
#         [-1.71252115]]), array([[-1.61318628],
#         [-1.65575786],
#         [-1.85087958],
#         [-1.78702168],
#         [-1.62382962],
#         [-1.61318628],
#         [-1.71252115],
#         [-1.54932838]]), array([[-1.65575786],
#         [-1.85087958],
#         [-1.78702168],
#         [-1.62382962],
#         [-1.61318628],
#         [-1.71252115],
#         [-1.54932838],
#         [-1.56351938]]), array([[-1.85087958],
#         [-1.78702168],
#         [-1.62382962],
#         [-1.61318628],
#         [-1.71252115],
#         [-1.54932838],
#         [-1.56351938],
#         [-1.43225556]]), array([[-1.78702168],
#         [-1.62382962],
#         [-1.61318628],
#         [-1.71252115],
#         [-1.54932838],
#         [-1.56351938],
#         [-1.43225556],
#         [-1.33646836]]), array([[-1.62382962],
#         [-1.61318628],
#         [-1.71252115],
#         [-1.54932838],
#         [-1.56351938],
#         [-1.43225556],
#         [-1.33646836],
#         [-1.04910816]]), array([[-1.61318628],
#         [-1.71252115],
#         [-1.54932838],
#         [-1.56351938],
#         [-1.43225556],
#         [-1.33646836],
#         [-1.04910816],
#         [-0.98879792]]), array([[-1.71252115],
#         [-1.54932838],
#         [-1.56351938],
#         [-1.43225556],
#         [-1.33646836],
#         [-1.04910816],
#         [-0.98879792],
#         [-0.99234558]]), array([[-1.54932838],
#         [-1.56351938],
#         [-1.43225556],
#         [-1.33646836],
#         [-1.04910816],
#         [-0.98879792],
#         [-0.99234558],
#         [-1.05620348]]), array([[-1.56351938],
#         [-1.43225556],
#         [-1.33646836],
#         [-1.04910816],
#         [-0.98879792],
#         [-0.99234558],
#         [-1.05620348],
#         [-1.0455605 ]]), array([[-1.43225556],
#         [-1.33646836],
#         [-1.04910816],
#         [-0.98879792],
#         [-0.99234558],
#         [-1.05620348],
#         [-1.0455605 ],
#         [-0.89655873]]), array([[-1.33646836],
#         [-1.04910816],
#         [-0.98879792],
#         [-0.99234558],
#         [-1.05620348],
#         [-1.0455605 ],
#         [-0.89655873],
#         [-0.91074973]]), array([[-1.04910816],
#         [-0.98879792],
#         [-0.99234558],
#         [-1.05620348],
#         [-1.0455605 ],
#         [-0.89655873],
#         [-0.91074973],
#         [-0.85398715]]), array([[-0.98879792],
#         [-0.99234558],
#         [-1.05620348],
#         [-1.0455605 ],
#         [-0.89655873],
#         [-0.91074973],
#         [-0.85398715],
#         [-1.12715635]]), array([[-0.99234558],
#         [-1.05620348],
#         [-1.0455605 ],
#         [-0.89655873],
#         [-0.91074973],
#         [-0.85398715],
#         [-1.12715635],
#         [-1.20165759]])]

# %%
y
# Out:
# [array([0.13935833]),
#  array([0.23869249]),
#  array([0.2103112]),
#  array([0.36995631]),
#  array([0.27771712]),
#  array([0.28481244]),
#  array([0.25997917]),
#  array([0.0506668]),
#  array([-0.03092905]),
#  array([-0.14445492]),
#  array([-0.14800187]),
#  array([-0.11962058]),
#  array([-0.20121749]),
#  array([-0.14445492]),
#  array([-0.17993082]),
#  array([-0.10543029]),
#  array([-0.14090725]),
#  array([-0.2508844]),
#  array([0.0364758]),
#  array([0.07550043]),
#  array([-0.13735924]),
#  array([-0.06995368]),
#  array([-0.03447671]),
#  array([0.11807272]),
#  array([0.05421482]),
#  array([0.05421482]),
#  array([-0.00254776]),
#  array([0.05776248]),
#  array([0.01164253]),
#  array([-0.11252596]),
#  array([-0.12671625]),
#  array([-0.10897795]),
#  array([-0.11607363]),
#  array([0.12516733]),
#  array([0.1748353]),
#  array([0.18192991]),
#  array([0.18192991]),
#  array([0.16773962]),
#  array([0.19257325]),
#  array([0.36995631]),
#  array([0.43026655]),
#  array([0.51186276]),
#  array([0.50831474]),
#  array([0.48702913]),
#  array([0.52605376]),
#  array([0.49057679]),
#  array([0.34157502]),
#  array([0.41607555]),
#  array([0.37350397]),
#  array([0.32738402]),
#  array([0.38769426]),
#  array([0.38059965]),
#  array([0.35576531]),
#  array([0.33093168]),
#  array([0.31674139]),
#  array([0.20676425]),
#  array([0.22804986]),
#  array([0.13226301]),
#  array([0.08969072]),
#  array([0.13226301]),
#  array([0.04002382]),
#  array([0.07904809]),
#  array([0.13581067]),
#  array([0.1606443]),
#  array([0.28126478]),
#  array([0.19966857]),
#  array([0.25288349]),
#  array([0.15354862]),
#  array([0.15709664]),
#  array([0.13935833]),
#  array([-0.09833497]),
#  array([-0.0273821]),
#  array([-0.02028642]),
#  array([-0.06995368]),
#  array([-0.00254776]),
#  array([-0.062858]),
#  array([-0.31829031]),
#  array([-0.21540778]),
#  array([-0.2366934]),
#  array([-0.13026392]),
#  array([-0.03802473]),
#  array([-0.15154953]),
#  array([-0.11607363]),
#  array([-0.10188263]),
#  array([-0.13381158]),
#  array([-0.09833497]),
#  array([0.19257325]),
#  array([0.10388172]),
#  array([-0.04157239]),
#  array([-0.11252596]),
#  array([-0.20831211]),
#  array([-0.09478695]),
#  array([-0.11962058]),
#  array([0.02583353]),
#  array([-0.19057416]),
#  array([-0.2508844]),
#  array([-0.46374407]),
#  array([-0.40698184]),
#  array([-0.43536278]),
#  array([-0.21895544]),
#  array([-0.09833497]),
#  array([-0.17993082]),
#  array([-0.19057416]),
#  array([-0.19057416]),
#  array([-0.05576339]),
#  array([-0.077049]),
#  array([-0.14800187]),
#  array([-0.17993082]),
#  array([-0.21895544]),
#  array([-0.79722457]),
#  array([-0.65531741]),
#  array([-0.61274583]),
#  array([-0.35376692]),
#  array([-0.25443206]),
#  array([-0.35731388]),
#  array([-0.70853304]),
#  array([-0.62693612]),
#  array([-0.5382446]),
#  array([-0.46729208]),
#  array([-0.33957592]),
#  array([-0.45310108]),
#  array([-0.47793436]),
#  array([-0.41762412]),
#  array([-0.54179261]),
#  array([-0.59855519]),
#  array([-0.63757946]),
#  array([-0.59500717]),
#  array([-0.82915281]),
#  array([-0.78658123]),
#  array([-0.90720171]),
#  array([-0.97460763]),
#  array([-1.03137021]),
#  array([-1.12360869]),
#  array([-1.16618098]),
#  array([-1.08813279]),
#  array([-0.83979615]),
#  array([-0.81851018]),
#  array([-0.83979615]),
#  array([-0.74755696]),
#  array([-0.96751195]),
#  array([-0.97815458]),
#  array([-0.97815458]),
#  array([-0.8859161]),
#  array([-0.80431918]),
#  array([-0.71562765]),
#  array([-0.6978897]),
#  array([-0.61984151]),
#  array([-0.72272333]),
#  array([-0.6836987]),
#  array([-0.60565051]),
#  array([-0.67305643]),
#  array([-0.75465228]),
#  array([-0.6978897]),
#  array([-0.74755696]),
#  array([-0.89655873]),
#  array([-0.61984151]),
#  array([-0.8575341]),
#  array([-0.86817744]),
#  array([-0.83624849]),
#  array([-0.8859161]),
#  array([-0.70143736]),
#  array([-0.36086154]),
#  array([0.06130943]),
#  array([-0.21540778]),
#  array([-0.17993082]),
#  array([-0.05576339]),
#  array([-0.28636101]),
#  array([-0.11962058]),
#  array([-0.08414468]),
#  array([0.15709664]),
#  array([0.32738402]),
#  array([-0.00254776]),
#  array([0.04711914]),
#  array([0.19257325]),
#  array([0.32383707]),
#  array([0.3486707]),
#  array([0.29545578]),
#  array([0.25997917]),
#  array([0.31319373]),
#  array([0.56862498]),
#  array([0.25288349]),
#  array([0.57926832]),
#  array([0.45155252]),
#  array([0.2883601]),
#  array([0.14290635]),
#  array([0.11452506]),
#  array([0.00099919]),
#  array([0.10388172]),
#  array([0.13581067]),
#  array([0.16419196]),
#  array([0.15354862]),
#  array([0.14645401]),
#  array([0.08969072]),
#  array([0.12871535]),
#  array([0.26352683]),
#  array([0.15709664]),
#  array([0.11097704]),
#  array([0.25997917]),
#  array([0.08259611]),
#  array([0.0506668]),
#  array([-0.18702649]),
#  array([-0.16574053]),
#  array([-0.20831211]),
#  array([-0.40343383]),
#  array([-0.48503003]),
#  array([-0.53114998]),
#  array([-0.48857769]),
#  array([-0.61984151]),
#  array([-0.51695898]),
#  array([-0.62338846]),
#  array([-0.71562765]),
#  array([-0.5701739]),
#  array([-0.67660409]),
#  array([-0.65176975]),
#  array([-0.6978897]),
#  array([-0.6978897]),
#  array([-0.72627099]),
#  array([-0.66596075]),
#  array([-0.62693612]),
#  array([-0.52405431]),
#  array([-0.66596075]),
#  array([-0.69434204]),
#  array([-0.93913102]),
#  array([-1.08458477]),
#  array([-1.08458477]),
#  array([-1.16972864]),
#  array([-1.25487251]),
#  array([-1.13779969]),
#  array([-1.25842017]),
#  array([-1.1910146]),
#  array([-1.06329916]),
#  array([-1.2052056]),
#  array([-1.02427453]),
#  array([-1.1094184]),
#  array([-1.38258866]),
#  array([-1.37549299]),
#  array([-1.06684611]),
#  array([-1.1590853]),
#  array([-1.18746659]),
#  array([-1.15199069]),
#  array([-1.1094184]),
#  array([-1.12715635]),
#  array([-1.12006174]),
#  array([-1.20165759]),
#  array([-1.29034912]),
#  array([-1.20875327]),
#  array([-1.25842017]),
#  array([-1.12006174]),
#  array([-1.19456227]),
#  array([-1.27970613]),
#  array([-1.24777683]),
#  array([-1.23713455]),
#  array([-1.0597515]),
#  array([-1.0455605]),
#  array([-1.0952274]),
#  array([-1.13425203]),
#  array([-1.16618098]),
#  array([-1.12006174]),
#  array([-0.99234558]),
#  array([-0.92848768]),
#  array([-0.83270047]),
#  array([-0.80077152]),
#  array([-0.74400894]),
#  array([-0.81496252]),
#  array([-0.83624849]),
#  array([-0.91429739]),
#  array([-0.86108176]),
#  array([-0.8575341]),
#  array([-0.67660409]),
#  array([-0.5843649]),
#  array([-0.60919817]),
#  array([-0.74755696]),
#  array([-0.59855519]),
#  array([-0.58081688]),
#  array([-0.6340318]),
#  array([-0.61984151]),
#  array([-0.21185977]),
#  array([-0.08059666]),
#  array([0.12516733]),
#  array([0.26352683]),
#  array([0.31674139]),
#  array([0.16773962]),
#  array([0.08614377]),
#  array([-0.06995368]),
#  array([-0.10897795]),
#  array([-0.1728362]),
#  array([-0.08769234]),
#  array([-0.04157239]),
#  array([-0.08059666]),
#  array([-0.16574053]),
#  array([-0.14090725]),
#  array([-0.15154953]),
#  array([-0.13381158]),
#  array([-0.21540778]),
#  array([-0.24024106]),
#  array([-0.3005513]),
#  array([-0.21540778]),
#  array([-0.33957592]),
#  array([-0.2508844]),
#  array([-0.34312359]),
#  array([-0.37505254]),
#  array([-0.26507539]),
#  array([-0.14800187]),
#  array([-0.10897795]),
#  array([-0.05931034]),
#  array([-0.19766948]),
#  array([-0.17638387]),
#  array([-0.20121749]),
#  array([-0.19766948]),
#  array([-0.23314644]),
#  array([-0.32183797]),
#  array([-0.45310108]),
#  array([-0.46374407]),
#  array([-0.43891079]),
#  array([-0.40343383]),
#  array([-0.56307822]),
#  array([-0.52405431]),
#  array([-0.4460054]),
#  array([-0.50631564]),
#  array([-0.39279084]),
#  array([-0.47438669]),
#  array([-0.69079438]),
#  array([-0.59855519]),
#  array([-0.40698184]),
#  array([-0.09833497]),
#  array([-0.24024106]),
#  array([-0.32893259]),
#  array([-0.1728362]),
#  array([-0.10543029]),
#  array([0.03292814]),
#  array([0.10742938]),
#  array([0.07195277]),
#  array([0.14645401]),
#  array([0.12871535]),
#  array([0.12871535]),
#  array([0.14645401]),
#  array([0.06840511]),
#  array([0.08259611]),
#  array([0.16773962]),
#  array([0.33093168]),
#  array([0.25288349]),
#  array([0.25288349]),
#  array([0.14290635]),
#  array([0.18547793]),
#  array([0.12516733]),
#  array([-0.10543029]),
#  array([-0.20831211]),
#  array([-0.14800187]),
#  array([-0.22605077]),
#  array([-0.09123929]),
#  array([0.00454685]),
#  array([-0.14445492]),
#  array([-0.19766948]),
#  array([-0.17993082]),
#  array([-0.07350134]),
#  array([-0.02028642]),
#  array([-0.06640601]),
#  array([-0.11607363]),
#  array([-0.077049]),
#  array([-0.08414468]),
#  array([-0.12671625]),
#  array([-0.03092905]),
#  array([-0.10897795]),
#  array([-0.06995368]),
#  array([-0.16574053]),
#  array([-0.18347848]),
#  array([-0.11252596]),
#  array([-0.18347848]),
#  array([-0.19057416]),
#  array([-0.04157239]),
#  array([-0.09833497]),
#  array([-0.03802473]),
#  array([-0.12671625]),
#  array([-0.32893259]),
#  array([-0.39279084]),
#  array([-0.40698184]),
#  array([-0.44955307]),
#  array([-0.33602826]),
#  array([-0.28281335]),
#  array([-0.29700364]),
#  array([-0.3147423]),
#  array([-0.20476515]),
#  array([0.0506668]),
#  array([0.03292814]),
#  array([-0.11607363]),
#  array([-0.11252596]),
#  array([-0.07350134]),
#  array([-0.12671625]),
#  array([-0.10897795]),
#  array([-0.11607363]),
#  array([-0.13381158]),
#  array([-0.17638387]),
#  array([-0.19057416]),
#  array([-0.26507539]),
#  array([-0.1728362]),
#  array([-0.24378907]),
#  array([-0.1728362]),
#  array([-0.20476515]),
#  array([-0.14090725]),
#  array([-0.02028642]),
#  array([-0.0131911]),
#  array([0.19257325]),
#  array([0.13935833]),
#  array([0.08969072]),
#  array([0.11807272]),
#  array([0.10742938]),
#  array([0.07550043]),
#  array([0.02228551]),
#  array([-0.13735924]),
#  array([-0.11252596]),
#  array([-0.18347848]),
#  array([-0.16574053]),
#  array([-0.19412182]),
#  array([-0.16928819]),
#  array([-0.08414468]),
#  array([0.10742938]),
#  array([0.33093168]),
#  array([0.15000096]),
#  array([0.56153037]),
#  array([0.51186276]),
#  array([0.51895808]),
#  array([0.65731651]),
#  array([0.76374705]),
#  array([0.87372419]),
#  array([0.90210548]),
#  array([0.98370169]),
#  array([1.08658386]),
#  array([1.07594088]),
#  array([1.25332394]),
#  array([1.21075236]),
#  array([1.12915544]),
#  array([1.18237107]),
#  array([1.2568716]),
#  array([1.35975413]),
#  array([1.49811256]),
#  array([1.64356667]),
#  array([1.71097259]),
#  array([1.71097259]),
#  array([1.7180672]),
#  array([1.6684003]),
#  array([1.62228106]),
#  array([1.65421001]),
#  array([1.73935387]),
#  array([1.69323392]),
#  array([1.75709183]),
#  array([1.7322582]),
#  array([1.70742457]),
#  array([1.67904363]),
#  array([1.76418715]),
#  array([1.68968591]),
#  array([1.70742457]),
#  array([1.66130462]),
#  array([1.62228106]),
#  array([1.61163772]),
#  array([1.53358953]),
#  array([1.4945649]),
#  array([1.26396692]),
#  array([1.26041926]),
#  array([1.31718184]),
#  array([1.16818007]),
#  array([1.21429931]),
#  array([1.18237107]),
#  array([1.17527539]),
#  array([1.06529754]),
#  array([1.07594088]),
#  array([0.9375821]),
#  array([1.04046392]),
#  array([1.02627363]),
#  array([0.94467777]),
#  array([0.90920081]),
#  array([0.80631863]),
#  array([0.70698447]),
#  array([0.74955605]),
#  array([0.72827009]),
#  array([0.89146215]),
#  array([0.94113011]),
#  array([0.89146215]),
#  array([0.86662887]),
#  array([0.85243858]),
#  array([0.9375821]),
#  array([0.9375821]),
#  array([1.2568716]),
#  array([1.31718184]),
#  array([1.01563064]),
#  array([0.90920081]),
#  array([1.17172773]),
#  array([1.07594088]),
#  array([0.99434467]),
#  array([0.91984344]),
#  array([0.87017653]),
#  array([0.64312622]),
#  array([0.68924581]),
#  array([0.64312622]),
#  array([0.64667423]),
#  array([0.66441219]),
#  array([0.66795985]),
#  array([0.72827009]),
#  array([0.83824758]),
#  array([0.89855782]),
#  array([0.9233911]),
#  array([0.83469957]),
#  array([0.94467777]),
#  array([0.94822472]),
#  array([1.10077415]),
#  array([1.09722649]),
#  array([0.91629648]),
#  array([0.9375821]),
#  array([1.10077415]),
#  array([1.01563064]),
#  array([0.9375821]),
#  array([1.05465491]),
#  array([1.10786983]),
#  array([1.09367954]),
#  array([1.12206083]),
#  array([0.99434467]),
#  array([0.87017653]),
#  array([0.83824758]),
#  array([0.83824758]),
#  array([1.02982164]),
#  array([1.11141749]),
#  array([1.34201547]),
#  array([1.18591802]),
#  array([1.10077415]),
#  array([1.25332394]),
#  array([1.22849031]),
#  array([1.22494265]),
#  array([1.28525289]),
#  array([1.3065385]),
#  array([1.48746958]),
#  array([1.64001901]),
#  array([1.72516288]),
#  array([1.13625112]),
#  array([1.20365668]),
#  array([1.1930137]),
#  array([1.28525289]),
#  array([1.17172773]),
#  array([1.16463241]),
#  array([1.16818007]),
#  array([1.07239322]),
#  array([1.17172773]),
#  array([1.17172773]),
#  array([1.0688452]),
#  array([0.97660601]),
#  array([0.89855782]),
#  array([0.78503267]),
#  array([0.56862498]),
#  array([0.586364]),
#  array([0.75310372]),
#  array([0.77438933]),
#  array([0.77084167]),
#  array([0.76374705]),
#  array([0.75665138]),
#  array([0.80277062]),
#  array([0.83824758]),
#  array([0.82760495]),
#  array([0.94822472]),
#  array([1.04755959]),
#  array([0.98370169]),
#  array([0.91274882]),
#  array([0.80631863]),
#  array([0.87017653]),
#  array([0.9233911]),
#  array([0.98724935]),
#  array([1.04046392]),
#  array([1.04046392]),
#  array([1.07948854]),
#  array([1.05110725]),
#  array([1.03691625]),
#  array([0.99434467]),
#  array([0.9233911]),
#  array([0.91984344]),
#  array([0.94822472]),
#  array([1.01563064]),
#  array([1.00498801]),
#  array([1.02627363]),
#  array([1.07594088]),
#  array([1.06529754]),
#  array([1.15753673]),
#  array([1.07239322]),
#  array([0.92693911]),
#  array([1.03691625]),
#  array([0.87727186]),
#  array([0.8595332]),
#  array([0.91274882]),
#  array([1.01563064]),
#  array([0.97305906]),
#  array([0.9695114]),
#  array([0.80631863]),
#  array([0.85243858]),
#  array([0.84889057]),
#  array([0.86308086]),
#  array([0.91629648]),
#  array([1.00853496]),
#  array([0.89855782]),
#  array([0.0967864]),
#  array([0.33802736]),
#  array([0.15354862]),
#  array([0.26707378]),
#  array([0.30964607]),
#  array([0.2883601]),
#  array([0.23514554]),
#  array([0.10033406]),
#  array([0.12871535]),
#  array([0.19966857]),
#  array([0.13581067]),
#  array([0.09323838]),
#  array([0.18547793]),
#  array([0.04002382]),
#  array([0.07550043]),
#  array([-0.0131911]),
#  array([0.06840511]),
#  array([0.05421482]),
#  array([0.12516733]),
#  array([0.11452506]),
#  array([0.13581067]),
#  array([0.15354862]),
#  array([0.12161967]),
#  array([0.11097704]),
#  array([0.09323838]),
#  array([0.18902559]),
#  array([0.12161967]),
#  array([0.08969072]),
#  array([0.00099919]),
#  array([-0.13735924]),
#  array([-0.22959878]),
#  array([-0.16219287]),
#  array([-0.01673876]),
#  array([0.06840511]),
#  array([0.00454685]),
#  array([-0.0131911]),
#  array([0.08614377]),
#  array([0.07550043]),
#  array([0.19257325]),
#  array([0.3344797]),
#  array([0.35931297]),
#  array([0.4480045]),
#  array([0.51186276]),
#  array([0.63248324]),
#  array([0.69634114]),
#  array([0.58281598]),
#  array([0.62893557]),
#  array([0.6998888]),
#  array([0.69634114]),
#  array([0.66795985]),
#  array([0.55798271]),
#  array([0.50122013]),
#  array([0.58991166]),
#  array([0.51186276]),
#  array([0.51186276]),
#  array([0.48348147]),
#  array([0.52250574]),
#  array([0.36995631]),
#  array([0.36640865]),
#  array([0.36640865]),
#  array([0.26707378]),
#  array([0.19257325]),
#  array([0.19257325]),
#  array([0.01873785]),
#  array([0.68924581]),
#  array([0.57572066]),
#  array([0.51186276]),
#  array([0.68924581]),
#  array([0.6218399]),
#  array([0.70343681]),
#  array([0.63248324]),
#  array([0.61829295]),
#  array([0.51186276]),
#  array([0.42317123]),
#  array([0.38059965]),
#  array([0.33093168]),
#  array([0.23869249]),
#  array([0.21740688]),
#  array([0.23869249]),
#  array([0.25643115]),
#  array([0.35931297]),
#  array([0.29900273]),
#  array([0.39478994]),
#  array([0.37350397]),
#  array([0.27771712]),
#  array([0.34512268]),
#  array([0.4480045]),
#  array([0.6502219]),
#  array([0.58991166]),
#  array([0.60764961]),
#  array([0.69634114]),
#  array([0.76729471]),
#  array([0.89855782]),
#  array([0.90920081]),
#  array([0.94822472]),
#  array([0.84534291]),
#  array([0.84179524]),
#  array([0.83115191]),
#  array([0.66795985]),
#  array([0.79922296]),
#  array([0.80631863]),
#  array([0.82050928]),
#  array([0.72827009]),
#  array([0.68924581]),
#  array([0.6360309]),
#  array([0.60055428]),
#  array([0.61119727]),
#  array([0.75310372]),
#  array([0.6218399]),
#  array([0.71053143]),
#  array([0.79922296]),
#  array([0.88791448]),
#  array([0.87372419]),
#  array([0.97660601]),
#  array([0.77793734]),
#  array([0.80277062]),
#  array([0.87017653]),
#  array([0.9375821]),
#  array([0.98370169]),
#  array([0.88081987]),
#  array([0.76374705]),
#  array([0.76374705]),
#  array([0.84889057]),
#  array([0.94113011]),
#  array([1.11851317]),
#  array([1.07239322]),
#  array([1.07594088]),
#  array([0.99434467]),
#  array([1.0191783]),
#  array([0.94822472]),
#  array([0.89146215]),
#  array([0.82760495]),
#  array([0.58281598]),
#  array([0.67505552]),
#  array([0.81341396]),
#  array([0.66795985]),
#  array([0.64312622]),
#  array([0.56507732]),
#  array([0.55443469]),
#  array([0.52250574]),
#  array([0.81341396]),
#  array([1.3065385]),
#  array([1.28880055]),
#  array([1.20365668]),
#  array([1.1930137]),
#  array([1.26041926]),
#  array([1.36684874]),
#  array([1.28170523]),
#  array([1.15753673]),
#  array([1.27815721]),
#  array([1.38103974]),
#  array([1.32427752]),
#  array([1.45199261]),
#  array([1.42361132]),
#  array([1.43425466]),
#  array([1.46973127]),
#  array([1.53713719]),
#  array([1.43780232]),
#  array([1.55132748]),
#  array([1.53713719]),
#  array([1.57970877]),
#  array([1.58325643]),
#  array([1.50166058]),
#  array([1.49811256]),
#  array([1.37394442]),
#  array([1.23558599]),
#  array([1.29944389]),
#  array([1.25332394]),
#  array([1.31008652]),
#  array([1.31363418]),
#  array([1.17527539]),
#  array([1.20365668]),
#  array([1.3065385]),
#  array([1.39523003]),
#  array([1.34911079]),
#  array([1.35620647]),
#  array([1.37394442]),
#  array([1.31008652]),
#  array([1.30299084]),
#  array([1.37749208]),
#  array([1.4945649]),
#  array([1.54068414]),
#  array([1.59744672]),
#  array([1.54777982]),
#  array([1.59389977]),
#  array([1.51585087]),
#  array([1.64001901]),
#  array([1.28170523]),
#  array([0.95886806]),
#  array([1.02627363]),
#  array([0.73536576]),
#  array([0.82050928]),
#  array([0.82050928]),
#  array([0.61119727]),
#  array([0.75310372]),
#  array([0.74600804]),
#  array([0.6856978]),
#  array([0.62893557]),
#  array([0.57572066]),
#  array([0.61829295]),
#  array([0.56153037]),
#  array([0.48702913]),
#  array([0.56507732]),
#  array([0.54024405]),
#  array([0.56507732]),
#  array([0.59345861]),
#  array([0.49767247]),
#  array([0.43026655]),
#  array([0.36995631]),
#  array([0.42671889]),
#  array([0.38414731]),
#  array([0.49767247]),
#  array([0.42317123]),
#  array([0.22804986]),
#  array([0.23869249]),
#  array([0.31319373]),
#  array([0.45510018]),
#  array([0.44090989]),
#  array([0.42317123]),
#  array([0.39478994]),
#  array([0.39478994]),
#  array([0.25997917]),
#  array([0.21385886]),
#  array([0.24224015]),
#  array([0.22804986]),
#  array([0.25997917]),
#  array([0.27771712]),
#  array([0.29545578]),
#  array([0.27416946]),
#  array([0.24933583]),
#  array([0.29545578]),
#  array([0.38414731]),
#  array([0.26352683]),
#  array([0.2103112]),
#  array([0.25288349]),
#  array([0.30964607]),
#  array([0.3344797]),
#  array([0.29545578]),
#  array([0.35221836]),
#  array([0.30964607]),
#  array([0.31319373]),
#  array([0.35931297]),
#  array([0.37705163]),
#  array([0.34157502]),
#  array([0.35221836]),
#  array([0.29190812]),
#  array([0.28126478]),
#  array([0.27416946]),
#  array([0.34157502]),
#  array([0.30255039]),
#  array([0.20676425]),
#  array([0.23869249]),
#  array([0.12871535]),
#  array([0.04711914]),
#  array([0.36640865]),
#  array([-0.0131911]),
#  array([-0.08769234]),
#  array([-0.16574053]),
#  array([0.10388172]),
#  array([0.11452506]),
#  array([0.01164253]),
#  array([-0.11252596]),
#  array([-0.14800187]),
#  array([-0.2508844]),
#  array([-0.3324806]),
#  array([-0.28636101]),
#  array([-0.16219287]),
#  array([-0.19766948]),
#  array([-0.14445492]),
#  array([0.00454685]),
#  array([-0.20476515]),
#  array([-0.25443206]),
#  array([-0.26152773]),
#  array([-0.10543029]),
#  array([-0.20121749]),
#  array([-0.27926568]),
#  array([-0.36086154]),
#  array([-0.42117213]),
#  array([-0.54534027]),
#  array([-0.55953127]),
#  array([-0.55243559]),
#  array([-0.46374407]),
#  array([-0.56307822]),
#  array([-0.48857769]),
#  array([-0.55243559]),
#  array([-0.59145951]),
#  array([-0.54179261]),
#  array([-0.63757946]),
#  array([-0.65886543]),
#  array([-0.67660409]),
#  array([-0.53469693]),
#  array([-0.55953127]),
#  array([-0.72627099]),
#  array([-0.74755696]),
#  array([-0.76884257]),
#  array([-0.86108176]),
#  array([-0.85398715]),
#  array([-0.79722457]),
#  array([-0.8859161]),
#  array([-0.98879792]),
#  array([-1.12715635]),
#  array([-1.13425203]),
#  array([-1.11651408]),
#  array([-1.13425203]),
#  array([-1.18746659]),
#  array([-1.31163508]),
#  array([-1.23713455]),
#  array([-1.25842017]),
#  array([-1.16618098]),
#  array([-1.1732763]),
#  array([-1.32227807]),
#  array([-1.38613632]),
#  array([-1.47482785]),
#  array([-1.60254295]),
#  array([-1.70187781]),
#  array([-1.64511523]),
#  array([-1.69833015]),
#  array([-1.79766502]),
#  array([-1.80475963]),
#  array([-1.73735478]),
#  array([-3.18834784]),
#  array([-3.05708438]),
#  array([-2.91872559]),
#  array([-2.78036645]),
#  array([-2.74843821]),
#  array([-2.46462496]),
#  array([-2.39721905]),
#  array([-2.45043467]),
#  array([-2.49655391]),
#  array([-2.72005621]),
#  array([-2.65265101]),
#  array([-2.60653106]),
#  array([-2.77327184]),
#  array([-2.94001156]),
#  array([-2.67748463]),
#  array([-2.76972382]),
#  array([-2.69522259]),
#  array([-2.74489055]),
#  array([-2.64555568]),
#  array([-2.54267316]),
#  array([-2.45398163]),
#  array([-2.40076671]),
#  array([-2.64200802]),
#  array([-2.65974668]),
#  array([-2.80874774]),
#  array([-2.78391411]),
#  array([-2.80165313]),
#  array([-2.67748463]),
#  array([-2.90453495]),
#  array([-3.01096478]),
#  array([-3.25930107]),
#  array([-3.22737212]),
#  array([-3.21672913]),
#  array([-3.26284873]),
#  array([-3.28058703]),
#  array([-3.35508792]),
#  array([-3.13158526]),
#  array([-3.06063204]),
#  array([-2.96129753]),
#  array([-3.0003218]),
#  array([-2.96839285]),
#  array([-3.03934607]),
#  array([-2.84422471]),
#  array([-2.7768195]),
#  array([-2.64910334]),
#  array([-2.61717439]),
#  array([-2.59588878]),
#  array([-2.47526795]),
#  array([-2.51783953]),
#  array([-2.47172029]),
#  array([-2.46817263]),
#  array([-1.6664012]),
#  array([-1.53513809]),
#  array([-1.51739943]),
#  array([-1.52449475]),
#  array([-1.4925658]),
#  array([-1.60609096]),
#  array([-1.51739943]),
#  array([-1.5067568]),
#  array([-1.54223271]),
#  array([-1.59899528]),
#  array([-1.5067568]),
#  array([-1.49611347]),
#  array([-1.4925658]),
#  array([-1.61318628]),
#  array([-1.65575786]),
#  array([-1.85087958]),
#  array([-1.78702168]),
#  array([-1.62382962]),
#  array([-1.61318628]),
#  array([-1.71252115]),
#  array([-1.54932838]),
#  array([-1.56351938]),
#  array([-1.43225556]),
#  array([-1.33646836]),
#  array([-1.04910816]),
#  array([-0.98879792]),
#  array([-0.99234558]),
#  array([-1.05620348]),
#  array([-1.0455605]),
#  array([-0.89655873]),
#  array([-0.91074973]),
#  array([-0.85398715]),
#  array([-1.12715635]),
#  array([-1.20165759]),
#  array([-1.05265582])]

# %%
X_train=np.array(X[:807])
y_train=np.array(y[:807])

# %%
X_test=np.array(X[807:])
y_test=np.array(y[807:])

# %%
X_train.shape
# Out:
# (807, 8, 1)

# %%
X_test.shape
# Out:
# (193, 8, 1)

# %%
y_train.shape
# Out:
# (807, 1)

# %%
y_test.shape
# Out:
# (193, 1)

# %%
b = 8 #b is batch size
w = 8 # w is window size
h = 200 #h is hidden layer
clip_margin = 4 
learning_rate = 0.001 
epochs = 200

# %%
inputs = tf.placeholder(tf.float32, [b, w, 1])
targets = tf.placeholder(tf.float32, [b, 1])

# %%
#Weights for the input gate
weights_input_gate = tf.Variable(tf.truncated_normal([1, h], stddev=0.05))
weights_input_hidden = tf.Variable(tf.truncated_normal([h, h], stddev=0.05))
bias_input = tf.Variable(tf.zeros([h]))

#weights for the forgot gate
weights_forget_gate = tf.Variable(tf.truncated_normal([1, h], stddev=0.05))
weights_forget_hidden = tf.Variable(tf.truncated_normal([h, h], stddev=0.05))
bias_forget = tf.Variable(tf.zeros([h]))

#weights for the output gate
weights_output_gate = tf.Variable(tf.truncated_normal([1, h], stddev=0.05))
weights_output_hidden = tf.Variable(tf.truncated_normal([h, h], stddev=0.05))
bias_output = tf.Variable(tf.zeros([h]))

#weights for the memory cell
weights_memory_cell = tf.Variable(tf.truncated_normal([1, h], stddev=0.05))
weights_memory_cell_hidden = tf.Variable(tf.truncated_normal([h, h], stddev=0.05))
bias_memory_cell = tf.Variable(tf.zeros([h]))

#Output layer weigts
weights_output = tf.Variable(tf.truncated_normal([h, 1], stddev=0.05))
bias_output_layer = tf.Variable(tf.zeros([1]))

# %%
def LSTM_cell(input, output, state):
    
    input_gate = tf.sigmoid(tf.matmul(input, weights_input_gate) + tf.matmul(output, weights_input_hidden) + bias_input)
    forget_gate = tf.sigmoid(tf.matmul(input, weights_forget_gate) + tf.matmul(output, weights_forget_hidden) + bias_forget)
    output_gate = tf.sigmoid(tf.matmul(input, weights_output_gate) + tf.matmul(output, weights_output_hidden) + bias_output)
    memory_cell = tf.tanh(tf.matmul(input, weights_memory_cell) + tf.matmul(output, weights_memory_cell_hidden) + bias_memory_cell)
    state = state * forget_gate + input_gate * memory_cell
    output = output_gate * tf.tanh(state)
    return state, output

# %%
outputs = []
for i in range(b): 
  
    batch_state = np.zeros([1, h], dtype=np.float32) 
    batch_output = np.zeros([1, h], dtype=np.float32)
    
    for j in range(w):
        batch_state, batch_output = LSTM_cell(tf.reshape(inputs[i][j], (-1, 1)),
                                              batch_state, batch_output)
        
    outputs.append(tf.matmul(batch_output, weights_output) + bias_output_layer)
outputs
# Out:
# [<tf.Tensor 'add_656:0' shape=(1, 1) dtype=float32>,
#  <tf.Tensor 'add_729:0' shape=(1, 1) dtype=float32>,
#  <tf.Tensor 'add_802:0' shape=(1, 1) dtype=float32>,
#  <tf.Tensor 'add_875:0' shape=(1, 1) dtype=float32>,
#  <tf.Tensor 'add_948:0' shape=(1, 1) dtype=float32>,
#  <tf.Tensor 'add_1021:0' shape=(1, 1) dtype=float32>,
#  <tf.Tensor 'add_1094:0' shape=(1, 1) dtype=float32>,
#  <tf.Tensor 'add_1167:0' shape=(1, 1) dtype=float32>]

# %%
losses = []

for i in range(len(outputs)):
    losses.append(tf.losses.mean_squared_error(tf.reshape(targets[i], (-1, 1)),
                                               outputs[i]))
    
loss = tf.reduce_mean(losses)

# %%
#we define optimizer with gradient clipping
gradients = tf.gradients(loss, tf.trainable_variables())
clipped, _ = tf.clip_by_global_norm(gradients, clip_margin)
optimizer = tf.train.AdamOptimizer(learning_rate)
trained_optimizer = optimizer.apply_gradients(zip(gradients, tf.trainable_variables()))

# %%
session = tf.Session()
session.run(tf.global_variables_initializer())
for i in range(epochs):
    traind_scores = []
    j = 0
    epoch_loss = []
    while(j + b) <= len(X_train):
        X_batch = X_train[j:j+b]
        y_batch = y_train[j:j+b]
        o, c, _ = session.run([outputs, loss, trained_optimizer], feed_dict={inputs:X_batch, targets:y_batch})
        epoch_loss.append(c)
        traind_scores.append(o)
        j += b
    if (i % 40) == 0:
        print('Epoch {}/{}'.format(i, epochs), ' Current loss: {}'.format(np.mean(epoch_loss)))
# Out:
# Epoch 0/200  Current loss: 0.09508194029331207
# Epoch 40/200  Current loss: 0.01598675735294819
# Epoch 80/200  Current loss: 0.015596196986734867
# Epoch 120/200  Current loss: 0.014485039748251438
# Epoch 160/200  Current loss: 0.013005262240767479

# %%
sup =[]
for i in range(len(traind_scores)):
    for j in range(len(traind_scores[i])):
        sup.append(traind_scores[i][j][0])

# %%
tests = []
i = 0
while i+b <= len(X_test): 
    o = session.run([outputs],feed_dict={inputs:X_test[i:i+b]})
    i += b
    tests.append(o)

# %%
tests_new = []
for i in range(len(tests)):
    for j in range(len(tests[i][0])):
        tests_new.append(tests[i][0][j])

# %%
tests
# Out:
# [[[array([[0.57436013]], dtype=float32),
#    array([[0.35128453]], dtype=float32),
#    array([[0.23770472]], dtype=float32),
#    array([[0.33380195]], dtype=float32),
#    array([[0.51242125]], dtype=float32),
#    array([[0.5223434]], dtype=float32),
#    array([[0.48095897]], dtype=float32),
#    array([[0.44291312]], dtype=float32)]],
#  [[array([[0.43760544]], dtype=float32),
#    array([[0.2990005]], dtype=float32),
#    array([[0.18810537]], dtype=float32),
#    array([[0.2576046]], dtype=float32),
#    array([[0.3015628]], dtype=float32),
#    array([[0.3408489]], dtype=float32),
#    array([[0.32825565]], dtype=float32),
#    array([[0.37225202]], dtype=float32)]],
#  [[array([[0.31705302]], dtype=float32),
#    array([[0.256583]], dtype=float32),
#    array([[0.2792744]], dtype=float32),
#    array([[0.37712854]], dtype=float32),
#    array([[0.37075633]], dtype=float32),
#    array([[0.24588525]], dtype=float32),
#    array([[0.18384783]], dtype=float32),
#    array([[0.3364079]], dtype=float32)]],
#  [[array([[0.37644675]], dtype=float32),
#    array([[0.34214073]], dtype=float32),
#    array([[0.35717663]], dtype=float32),
#    array([[0.342794]], dtype=float32),
#    array([[0.32782325]], dtype=float32),
#    array([[0.33884722]], dtype=float32),
#    array([[0.40720728]], dtype=float32),
#    array([[0.43410644]], dtype=float32)]],
#  [[array([[0.35798228]], dtype=float32),
#    array([[0.34463304]], dtype=float32),
#    array([[0.30780458]], dtype=float32),
#    array([[0.283523]], dtype=float32),
#    array([[0.36208728]], dtype=float32),
#    array([[0.40625668]], dtype=float32),
#    array([[0.2817216]], dtype=float32),
#    array([[0.22695242]], dtype=float32)]],
#  [[array([[0.15428618]], dtype=float32),
#    array([[0.10294785]], dtype=float32),
#    array([[0.2717828]], dtype=float32),
#    array([[0.17266355]], dtype=float32),
#    array([[0.01266026]], dtype=float32),
#    array([[-0.3735267]], dtype=float32),
#    array([[0.15937817]], dtype=float32),
#    array([[-0.00261437]], dtype=float32)]],
#  [[array([[-0.0320693]], dtype=float32),
#    array([[-0.07214731]], dtype=float32),
#    array([[-0.18898097]], dtype=float32),
#    array([[-0.20183136]], dtype=float32),
#    array([[-0.26965055]], dtype=float32),
#    array([[-0.23247698]], dtype=float32),
#    array([[-0.08201206]], dtype=float32),
#    array([[-0.1204493]], dtype=float32)]],
#  [[array([[-0.12170249]], dtype=float32),
#    array([[0.11673106]], dtype=float32),
#    array([[-0.10315801]], dtype=float32),
#    array([[-0.18479349]], dtype=float32),
#    array([[-0.2381776]], dtype=float32),
#    array([[-0.03186016]], dtype=float32),
#    array([[-0.23189029]], dtype=float32),
#    array([[-0.28276914]], dtype=float32)]],
#  [[array([[-0.3028983]], dtype=float32),
#    array([[-0.39096472]], dtype=float32),
#    array([[-0.46080142]], dtype=float32),
#    array([[-0.5489809]], dtype=float32),
#    array([[-0.43914217]], dtype=float32),
#    array([[-0.35971645]], dtype=float32),
#    array([[-0.46832418]], dtype=float32),
#    array([[-0.47401428]], dtype=float32)]],
#  [[array([[-0.5067074]], dtype=float32),
#    array([[-0.57530147]], dtype=float32),
#    array([[-0.53191894]], dtype=float32),
#    array([[-0.61715615]], dtype=float32),
#    array([[-0.5773184]], dtype=float32),
#    array([[-0.6625814]], dtype=float32),
#    array([[-0.46830422]], dtype=float32),
#    array([[-0.55107826]], dtype=float32)]],
#  [[array([[-0.70853]], dtype=float32),
#    array([[-0.67588305]], dtype=float32),
#    array([[-0.74841624]], dtype=float32),
#    array([[-0.81908166]], dtype=float32),
#    array([[-0.8127495]], dtype=float32),
#    array([[-0.7709304]], dtype=float32),
#    array([[-0.8192417]], dtype=float32),
#    array([[-0.8812616]], dtype=float32)]],
#  [[array([[-1.0400722]], dtype=float32),
#    array([[-1.0834384]], dtype=float32),
#    array([[-1.0540243]], dtype=float32),
#    array([[-1.0358081]], dtype=float32),
#    array([[-1.0512207]], dtype=float32),
#    array([[-1.1711836]], dtype=float32),
#    array([[-1.1152537]], dtype=float32),
#    array([[-1.2055092]], dtype=float32)]],
#  [[array([[-1.0373145]], dtype=float32),
#    array([[-1.127946]], dtype=float32),
#    array([[-1.1527785]], dtype=float32),
#    array([[-1.173169]], dtype=float32),
#    array([[-1.3705881]], dtype=float32),
#    array([[-1.3452165]], dtype=float32),
#    array([[-1.5488912]], dtype=float32),
#    array([[-1.4388063]], dtype=float32)]],
#  [[array([[-1.4115882]], dtype=float32),
#    array([[-1.4531502]], dtype=float32),
#    array([[-1.4121773]], dtype=float32),
#    array([[-1.411813]], dtype=float32),
#    array([[-1.8083162]], dtype=float32),
#    array([[-2.0022686]], dtype=float32),
#    array([[-2.4968994]], dtype=float32),
#    array([[-1.9512651]], dtype=float32)]],
#  [[array([[-2.6967196]], dtype=float32),
#    array([[-1.7348853]], dtype=float32),
#    array([[-2.0219624]], dtype=float32),
#    array([[-1.7768757]], dtype=float32),
#    array([[-1.906036]], dtype=float32),
#    array([[-1.852653]], dtype=float32),
#    array([[-1.9567767]], dtype=float32),
#    array([[-1.8946606]], dtype=float32)]],
#  [[array([[-1.8968031]], dtype=float32),
#    array([[-2.1554654]], dtype=float32),
#    array([[-1.9208335]], dtype=float32),
#    array([[-2.029058]], dtype=float32),
#    array([[-2.0036516]], dtype=float32),
#    array([[-2.0636284]], dtype=float32),
#    array([[-1.8412018]], dtype=float32),
#    array([[-1.8268559]], dtype=float32)]],
#  [[array([[-1.694733]], dtype=float32),
#    array([[-1.9201795]], dtype=float32),
#    array([[-1.8056905]], dtype=float32),
#    array([[-1.9193811]], dtype=float32),
#    array([[-1.9827787]], dtype=float32),
#    array([[-1.9116987]], dtype=float32),
#    array([[-2.022641]], dtype=float32),
#    array([[-1.8600914]], dtype=float32)]],
#  [[array([[-2.0384037]], dtype=float32),
#    array([[-2.0607104]], dtype=float32),
#    array([[-2.0026467]], dtype=float32),
#    array([[-2.160114]], dtype=float32),
#    array([[-1.8915612]], dtype=float32),
#    array([[-2.2763553]], dtype=float32),
#    array([[-1.9525143]], dtype=float32),
#    array([[-2.1757116]], dtype=float32)]],
#  [[array([[-1.9204893]], dtype=float32),
#    array([[-1.9628611]], dtype=float32),
#    array([[-2.2357829]], dtype=float32),
#    array([[-2.024715]], dtype=float32),
#    array([[-2.2095833]], dtype=float32),
#    array([[-2.0030692]], dtype=float32),
#    array([[-2.0925076]], dtype=float32),
#    array([[-2.051965]], dtype=float32)]],
#  [[array([[-1.9894263]], dtype=float32),
#    array([[-2.048113]], dtype=float32),
#    array([[-1.8618386]], dtype=float32),
#    array([[-1.9705385]], dtype=float32),
#    array([[-1.7803078]], dtype=float32),
#    array([[-1.8208205]], dtype=float32),
#    array([[-1.8085291]], dtype=float32),
#    array([[-1.2435023]], dtype=float32)]],
#  [[array([[-1.0914326]], dtype=float32),
#    array([[-0.89214367]], dtype=float32),
#    array([[-1.314417]], dtype=float32),
#    array([[-1.212274]], dtype=float32),
#    array([[-1.3127998]], dtype=float32),
#    array([[-1.4216845]], dtype=float32),
#    array([[-1.2858061]], dtype=float32),
#    array([[-1.3222363]], dtype=float32)]],
#  [[array([[-1.299428]], dtype=float32),
#    array([[-1.2342987]], dtype=float32),
#    array([[-1.2214955]], dtype=float32),
#    array([[-1.292954]], dtype=float32),
#    array([[-1.3037119]], dtype=float32),
#    array([[-1.3387455]], dtype=float32),
#    array([[-1.4661304]], dtype=float32),
#    array([[-1.4209429]], dtype=float32)]],
#  [[array([[-1.4056739]], dtype=float32),
#    array([[-1.3591002]], dtype=float32),
#    array([[-1.4385475]], dtype=float32),
#    array([[-1.2806847]], dtype=float32),
#    array([[-1.2986461]], dtype=float32),
#    array([[-1.1990385]], dtype=float32),
#    array([[-1.1065414]], dtype=float32),
#    array([[-0.890008]], dtype=float32)]],
#  [[array([[-0.8707392]], dtype=float32),
#    array([[-0.8277733]], dtype=float32),
#    array([[-0.94578105]], dtype=float32),
#    array([[-0.88094974]], dtype=float32),
#    array([[-0.7758842]], dtype=float32),
#    array([[-0.800168]], dtype=float32),
#    array([[-0.7947173]], dtype=float32),
#    array([[-0.9879518]], dtype=float32)]]]

# %%
tests_new
# Out:
# [array([[0.57436013]], dtype=float32),
#  array([[0.35128453]], dtype=float32),
#  array([[0.23770472]], dtype=float32),
#  array([[0.33380195]], dtype=float32),
#  array([[0.51242125]], dtype=float32),
#  array([[0.5223434]], dtype=float32),
#  array([[0.48095897]], dtype=float32),
#  array([[0.44291312]], dtype=float32),
#  array([[0.43760544]], dtype=float32),
#  array([[0.2990005]], dtype=float32),
#  array([[0.18810537]], dtype=float32),
#  array([[0.2576046]], dtype=float32),
#  array([[0.3015628]], dtype=float32),
#  array([[0.3408489]], dtype=float32),
#  array([[0.32825565]], dtype=float32),
#  array([[0.37225202]], dtype=float32),
#  array([[0.31705302]], dtype=float32),
#  array([[0.256583]], dtype=float32),
#  array([[0.2792744]], dtype=float32),
#  array([[0.37712854]], dtype=float32),
#  array([[0.37075633]], dtype=float32),
#  array([[0.24588525]], dtype=float32),
#  array([[0.18384783]], dtype=float32),
#  array([[0.3364079]], dtype=float32),
#  array([[0.37644675]], dtype=float32),
#  array([[0.34214073]], dtype=float32),
#  array([[0.35717663]], dtype=float32),
#  array([[0.342794]], dtype=float32),
#  array([[0.32782325]], dtype=float32),
#  array([[0.33884722]], dtype=float32),
#  array([[0.40720728]], dtype=float32),
#  array([[0.43410644]], dtype=float32),
#  array([[0.35798228]], dtype=float32),
#  array([[0.34463304]], dtype=float32),
#  array([[0.30780458]], dtype=float32),
#  array([[0.283523]], dtype=float32),
#  array([[0.36208728]], dtype=float32),
#  array([[0.40625668]], dtype=float32),
#  array([[0.2817216]], dtype=float32),
#  array([[0.22695242]], dtype=float32),
#  array([[0.15428618]], dtype=float32),
#  array([[0.10294785]], dtype=float32),
#  array([[0.2717828]], dtype=float32),
#  array([[0.17266355]], dtype=float32),
#  array([[0.01266026]], dtype=float32),
#  array([[-0.3735267]], dtype=float32),
#  array([[0.15937817]], dtype=float32),
#  array([[-0.00261437]], dtype=float32),
#  array([[-0.0320693]], dtype=float32),
#  array([[-0.07214731]], dtype=float32),
#  array([[-0.18898097]], dtype=float32),
#  array([[-0.20183136]], dtype=float32),
#  array([[-0.26965055]], dtype=float32),
#  array([[-0.23247698]], dtype=float32),
#  array([[-0.08201206]], dtype=float32),
#  array([[-0.1204493]], dtype=float32),
#  array([[-0.12170249]], dtype=float32),
#  array([[0.11673106]], dtype=float32),
#  array([[-0.10315801]], dtype=float32),
#  array([[-0.18479349]], dtype=float32),
#  array([[-0.2381776]], dtype=float32),
#  array([[-0.03186016]], dtype=float32),
#  array([[-0.23189029]], dtype=float32),
#  array([[-0.28276914]], dtype=float32),
#  array([[-0.3028983]], dtype=float32),
#  array([[-0.39096472]], dtype=float32),
#  array([[-0.46080142]], dtype=float32),
#  array([[-0.5489809]], dtype=float32),
#  array([[-0.43914217]], dtype=float32),
#  array([[-0.35971645]], dtype=float32),
#  array([[-0.46832418]], dtype=float32),
#  array([[-0.47401428]], dtype=float32),
#  array([[-0.5067074]], dtype=float32),
#  array([[-0.57530147]], dtype=float32),
#  array([[-0.53191894]], dtype=float32),
#  array([[-0.61715615]], dtype=float32),
#  array([[-0.5773184]], dtype=float32),
#  array([[-0.6625814]], dtype=float32),
#  array([[-0.46830422]], dtype=float32),
#  array([[-0.55107826]], dtype=float32),
#  array([[-0.70853]], dtype=float32),
#  array([[-0.67588305]], dtype=float32),
#  array([[-0.74841624]], dtype=float32),
#  array([[-0.81908166]], dtype=float32),
#  array([[-0.8127495]], dtype=float32),
#  array([[-0.7709304]], dtype=float32),
#  array([[-0.8192417]], dtype=float32),
#  array([[-0.8812616]], dtype=float32),
#  array([[-1.0400722]], dtype=float32),
#  array([[-1.0834384]], dtype=float32),
#  array([[-1.0540243]], dtype=float32),
#  array([[-1.0358081]], dtype=float32),
#  array([[-1.0512207]], dtype=float32),
#  array([[-1.1711836]], dtype=float32),
#  array([[-1.1152537]], dtype=float32),
#  array([[-1.2055092]], dtype=float32),
#  array([[-1.0373145]], dtype=float32),
#  array([[-1.127946]], dtype=float32),
#  array([[-1.1527785]], dtype=float32),
#  array([[-1.173169]], dtype=float32),
#  array([[-1.3705881]], dtype=float32),
#  array([[-1.3452165]], dtype=float32),
#  array([[-1.5488912]], dtype=float32),
#  array([[-1.4388063]], dtype=float32),
#  array([[-1.4115882]], dtype=float32),
#  array([[-1.4531502]], dtype=float32),
#  array([[-1.4121773]], dtype=float32),
#  array([[-1.411813]], dtype=float32),
#  array([[-1.8083162]], dtype=float32),
#  array([[-2.0022686]], dtype=float32),
#  array([[-2.4968994]], dtype=float32),
#  array([[-1.9512651]], dtype=float32),
#  array([[-2.6967196]], dtype=float32),
#  array([[-1.7348853]], dtype=float32),
#  array([[-2.0219624]], dtype=float32),
#  array([[-1.7768757]], dtype=float32),
#  array([[-1.906036]], dtype=float32),
#  array([[-1.852653]], dtype=float32),
#  array([[-1.9567767]], dtype=float32),
#  array([[-1.8946606]], dtype=float32),
#  array([[-1.8968031]], dtype=float32),
#  array([[-2.1554654]], dtype=float32),
#  array([[-1.9208335]], dtype=float32),
#  array([[-2.029058]], dtype=float32),
#  array([[-2.0036516]], dtype=float32),
#  array([[-2.0636284]], dtype=float32),
#  array([[-1.8412018]], dtype=float32),
#  array([[-1.8268559]], dtype=float32),
#  array([[-1.694733]], dtype=float32),
#  array([[-1.9201795]], dtype=float32),
#  array([[-1.8056905]], dtype=float32),
#  array([[-1.9193811]], dtype=float32),
#  array([[-1.9827787]], dtype=float32),
#  array([[-1.9116987]], dtype=float32),
#  array([[-2.022641]], dtype=float32),
#  array([[-1.8600914]], dtype=float32),
#  array([[-2.0384037]], dtype=float32),
#  array([[-2.0607104]], dtype=float32),
#  array([[-2.0026467]], dtype=float32),
#  array([[-2.160114]], dtype=float32),
#  array([[-1.8915612]], dtype=float32),
#  array([[-2.2763553]], dtype=float32),
#  array([[-1.9525143]], dtype=float32),
#  array([[-2.1757116]], dtype=float32),
#  array([[-1.9204893]], dtype=float32),
#  array([[-1.9628611]], dtype=float32),
#  array([[-2.2357829]], dtype=float32),
#  array([[-2.024715]], dtype=float32),
#  array([[-2.2095833]], dtype=float32),
#  array([[-2.0030692]], dtype=float32),
#  array([[-2.0925076]], dtype=float32),
#  array([[-2.051965]], dtype=float32),
#  array([[-1.9894263]], dtype=float32),
#  array([[-2.048113]], dtype=float32),
#  array([[-1.8618386]], dtype=float32),
#  array([[-1.9705385]], dtype=float32),
#  array([[-1.7803078]], dtype=float32),
#  array([[-1.8208205]], dtype=float32),
#  array([[-1.8085291]], dtype=float32),
#  array([[-1.2435023]], dtype=float32),
#  array([[-1.0914326]], dtype=float32),
#  array([[-0.89214367]], dtype=float32),
#  array([[-1.314417]], dtype=float32),
#  array([[-1.212274]], dtype=float32),
#  array([[-1.3127998]], dtype=float32),
#  array([[-1.4216845]], dtype=float32),
#  array([[-1.2858061]], dtype=float32),
#  array([[-1.3222363]], dtype=float32),
#  array([[-1.299428]], dtype=float32),
#  array([[-1.2342987]], dtype=float32),
#  array([[-1.2214955]], dtype=float32),
#  array([[-1.292954]], dtype=float32),
#  array([[-1.3037119]], dtype=float32),
#  array([[-1.3387455]], dtype=float32),
#  array([[-1.4661304]], dtype=float32),
#  array([[-1.4209429]], dtype=float32),
#  array([[-1.4056739]], dtype=float32),
#  array([[-1.3591002]], dtype=float32),
#  array([[-1.4385475]], dtype=float32),
#  array([[-1.2806847]], dtype=float32),
#  array([[-1.2986461]], dtype=float32),
#  array([[-1.1990385]], dtype=float32),
#  array([[-1.1065414]], dtype=float32),
#  array([[-0.890008]], dtype=float32),
#  array([[-0.8707392]], dtype=float32),
#  array([[-0.8277733]], dtype=float32),
#  array([[-0.94578105]], dtype=float32),
#  array([[-0.88094974]], dtype=float32),
#  array([[-0.7758842]], dtype=float32),
#  array([[-0.800168]], dtype=float32),
#  array([[-0.7947173]], dtype=float32),
#  array([[-0.9879518]], dtype=float32)]

# %%
test_results = []
for i in range(1000):
    if i >= 808:
        test_results.append(tests_new[i-808])
    else:
        test_results.append(None)

# %%
plt.figure(figsize=(16, 7))
plt.plot(sup,'r',label='Training data')
plt.plot(test_results,'g', label='Testing data')
plt.xlabel('Days')
plt.ylabel('Closing price of stock')
plt.legend()
plt.show()

# %%
#plt.figure(figsize=(16, 7))
plt.plot(sup,'r',label='Training data')
plt.plot(scaled_data,label='Original data')
plt.plot(test_results,'g', label='Testing data')
plt.title('Stock Price Prediction')
plt.xlabel('Days')
plt.ylabel('Closing price of stock')
plt.legend()
plt.show()
